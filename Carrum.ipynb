# %% [markdown]
# # Complete code with Automation

# %%
import re
import pdfplumber
import os
import pandas as pd


# Code 1: Process invoices with specific format
def process_invoice_pdf(pdf_path):
    data = {
        "Chassis Number": "Not found",
        "Color": "Not found",
        "Place of Supply": "Not found",
        "From": "Not found",
        "Invoice No.": "Not found",
        "Invoice Date": "Not found",
        "Owner": "Not found",
        "Ex-showroom Price": "₹6,41,500",  # Fixed value
        "Total Invoice Amount": "Not found",
        "Discount": "Not found",
        "Variant Description": "Not found",
        "Engine Number": "Not found",
    }

    
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            lines = page.extract_text().split("\n")  # Extract and split text into lines

            for line in lines:
                # Debugging: Uncomment to print each line
                
                #print(f"Line: {line}")

                # 1. Chassis Number
                if "Vehicle ID" in line:
                    match = re.search(r"Vehicle ID\s*:\s*([A-Z0-9]+)", line)
                    if match:
                        data["Chassis Number"] = match.group(1)

                # 2. Engine Number
                if data["Chassis Number"] != "Not found" and "Superior" in line:
                    chassis_match = re.search(data["Chassis Number"], line)
                    if chassis_match:
                        engine_match = re.search(rf"{data['Chassis Number']}\s+([A-Z0-9\s]+)\s+Superior", line)
                        if engine_match:
                            data["Engine Number"] = engine_match.group(1).strip()

                # 3. Color
                if "Superior" in line:
                    match = re.search(r"(Superior\s\w+-\d+U)", line, re.IGNORECASE)
                    if match:
                        data["Color"] = match.group(1)

                # 4. Place of Supply
                if "Place of Supply" in line:
                    match = re.search(r"Place of Supply\s*:\s*([\w\s]+\(\d+\))", line)
                    if match:
                        data["Place of Supply"] = match.group(1)

                # 5. From (Dealer Information)
                if "For" in line and "PVT LTD" in line:
                    match = re.search(r"For\s+([\w\s\.\-]+PVT LTD)", line, re.IGNORECASE)
                    if match:
                        data["From"] = match.group(1).strip()

                # 6. Invoice No.
                if "Invoice No." in line:
                    # Look for "Invoice No." and capture it
                    match = re.search(r"Invoice No\.\s*[:\-]?\s*([\w\/\-]+)", line)
                    if match:
                        data["Invoice No."] = match.group(1)

                # 7. Invoice Date
                if "Invoice Date" in line:
                    match = re.search(r"Invoice Date\s*:\s*([\d/]+\s+\d{2}:\d{2}\s+[APM]{2})", line)
                    if match:
                        data["Invoice Date"] = match.group(1)

                # 8. Owner
                if "Sold To" in line:
                    # This will match the "Sold To" line and capture everything after "Sold To :"
                    match = re.search(r"Sold To\s*:\s*(.+)", line, re.IGNORECASE)
                    if match:
                        data["Owner"] = match.group(1).strip()
    

                # 9. Total Invoice Amount
                if "Total Invoice Amount" in line:
                    match = re.search(r"Total Invoice Amount\s*:\s*([\d,]+\.\d{2})", line)
                    if match:
                        data["Total Invoice Amount"] = match.group(1)

                # 10. Variant Description
                if "PRICE OF ONE" in line:
                    match = re.search(r"PRICE OF ONE\s+([\w\s]+)-", line)
                    if match:
                        data["Variant Description"] = match.group(1).strip()

    # Calculate Discount
    if data["Total Invoice Amount"] != "Not found":
        ex_showroom_price = 641500.00
        total_invoice = float(data["Total Invoice Amount"].replace(",", ""))
        data["Discount"] = f"₹{ex_showroom_price - total_invoice:.2f}"

    return data

# Code 2: Process insurance policy PDFs with specific company
def process_insurance_pdf_shreyash(pdf_path):
    extracted_details = {
        "Chassis Number": None,
        "Insurance Company": "Go Digit General Insurance Ltd",
        "Policy Number": None,
        "INSURED’S DECLARED VALUE (IDV)": None,
        "Insurance Premium": None,
        "Start Date": None,
        "End Date": None
    }


    with pdfplumber.open(pdf_path) as pdf:
        for page_number, page in enumerate(pdf.pages):
            lines = page.extract_text().split("\n")  # Extract and split text into lines
            #print(f"--- Page {page_number + 1} ---")  # Debugging: Print page number
            
            for i, line in enumerate(lines):
                #print(f"Line {i}: {line.strip()}")  # Debugging: Print each line

                # 1.Chassis Number 
                if "Vehicle Identification No." in line:
                    match = re.search(r"Vehicle Identification No\.\s+([A-Z0-9]+)", line)
                    if match:
                        extracted_details["Chassis Number"] = match.group(1)
                       # print(f"Extracted Chassis Number: {extracted_details['Chassis Number']}")  # Debugging
               
                # 2. Policy Number
                if "Policy No" in line:
                    match = re.search(r"Policy No\s+(\w+)", line)
                    if match:
                        extracted_details["Policy Number"] = match.group(1)
                      #  print(f"Extracted Policy Number: {extracted_details['Policy Number']}")  # Debugging

                # 3. INSURED’S DECLARED VALUE (IDV)
                if "Total IDV ₹" in line:
                    match = re.search(r"Total IDV ₹\s*([\d,]+)", line)
                    if match:
                        extracted_details["INSURED’S DECLARED VALUE (IDV)"] = match.group(1).replace(",", "")
                      #  print(f"Extracted IDV: {extracted_details['INSURED’S DECLARED VALUE (IDV)']}")  # Debugging

                # 4. Insurance Premium
                if "Gross Premium Paid ₹" in line:
                    match = re.search(r"Gross Premium Paid ₹\s*([\d,]+)", line)
                    if match:
                        extracted_details["Insurance Premium"] = match.group(1).replace(",", "")
                      #  print(f"Extracted Insurance Premium: {extracted_details['Insurance Premium']}")  # Debugging

                # 5. Start Date
                if "Period of Insurance" in line:
                    match = re.search(r"Period of Insurance\s+(\d{2}-[A-Z]{3}-\d{4})", line)
                    if match:
                        extracted_details["Start Date"] = match.group(1)
                      #  print(f"Extracted Start Date: {extracted_details['Start Date']}")  # Debugging

                # 6. End Date
                if "to" in line and "Period of Insurance" in line:
                    match = re.search(r"to\s+(\d{2}-[A-Z]{3}-\d{4})", line)
                    if match:
                        extracted_details["End Date"] = match.group(1)
                      #  print(f"Extracted End Date: {extracted_details['End Date']}")  # Debugging

                # # 7. Insurance Company
                # if "T h i s i s n o t a p a r t o f t h e p o l i c y d o c u m e n t" in line:
                #     if i + 1 < len(lines):  # Check if next line exists
                #         extracted_details["Insurance Company"] = lines[i + 1].strip()
                #        # print(f"Extracted Insurance Company: {extracted_details['Insurance Company']}")  # Debugging

                

    return extracted_details




# Code 3: Process insurance PDFs with SBI-specific format
def process_insurance_pdf_sbi(pdf_path):
    extracted_details= {
        "Chassis Number": None,
        "Insurance Company": "SBI General Insurance Company Limited",
        "Policy Number": None,
        "INSURED’S DECLARED VALUE (IDV)": None,
        "Insurance Premium": None,
        "Start Date": None,
        "End Date": None
        
    }


    with pdfplumber.open(pdf_path) as pdf:
        for page_number, page in enumerate(pdf.pages):
            lines = page.extract_text().split("\n")  # Extract and split text into lines
            #print(f"--- Page {page_number + 1} ---")  # Debugging: Print page number
            
            for i, line in enumerate(lines):
                #print(f"Line {i}: {line.strip()}")  # Debugging: Print each line

                # 1. Chassis Number 
                if "Chassis Number" in line:
                    match = re.search(r"Chassis Number\s+([A-Z0-9]+)", line)
                    if match:
                        extracted_details["Chassis Number"] = match.group(1)
                       # print(f"Extracted Chassis Number: {extracted_details['Chassis Number']}")  # Debugging
                
                # 2. Policy Number
                if "Your Policy No. :" in line:
                    match = re.search(r"Your Policy No\. :(\d+)", line)
                    if match:
                        extracted_details["Policy Number"] = match.group(1)
                        #print(f"Extracted Policy Number: {extracted_details['Policy Number']}")  # Debugging

                # 3. INSURED’S DECLARED VALUE (IDV)
                if "INSURED’S DECLARED VALUE (IDV)" in line:
                    if i + 4 < len(lines):  # Check if 4th line after exists
                        idv_line = lines[i + 4].strip()
                        match = re.search(r"(\d{1,3}(,\d{3})*(\.\d{2})?)", idv_line)
                        if match:
                            extracted_details["INSURED’S DECLARED VALUE (IDV)"] = match.group(1).split(".")[0]
                        #    print(f"Extracted IDV: {extracted_details['INSURED’S DECLARED VALUE (IDV)']}")  # Debugging

                # 4. Insurance Premium
                if "Total Premium Collected" in line:
                    match = re.search(r"Total Premium Collected\s+([\d,]+\.\d{2})", line)
                    if match:
                        extracted_details["Insurance Premium"] = match.group(1)
                      #  print(f"Extracted Insurance Premium: {extracted_details['Insurance Premium']}")  # Debugging

                # 5. Start Date
                if "Period of Insurance : From :" in line:
                    match = re.search(r"From\s*:(\d{2}/\d{2}/\d{4})", line)
                    if match:
                        extracted_details["Start Date"] = match.group(1)
                      #  print(f"Extracted Start Date: {extracted_details['Start Date']}")  # Debugging

                # 6. End Date
                if "Period of Insurance : From :" in line:
                    match = re.search(r"Midnight of:\s*(\d{2}/\d{2}/\d{4})", line)
                    if match:
                        extracted_details["End Date"] = match.group(1)
                      #  print(f"Extracted End Date: {extracted_details['End Date']}")  # Debugging
    
                # # 7.Insurance Company
                # if "The Postal Address of your SBI General Branch that will service you in future is:" in line:
                #     if i + 1 < len(lines):  # Check if next line exists
                #         extracted_details["Insurance Company"] = lines[i + 1].strip()
                #         #print(f"Extracted Insurance Company: {extracted_details['Insurance Company']}")  # Debugging



    return extracted_details


def process_pdf_based_on_type(pdf_path):
    with pdfplumber.open(pdf_path) as pdf:
        first_page_text = pdf.pages[0].extract_text()

    if "TAX / VEHICLE & CHARGES INVOICE" in first_page_text:
        print("Processing Invoice PDF...")
        return process_invoice_pdf(pdf_path)
    elif "SHREYASH AUTOMOTIVES PRIVATE LIMIT" in first_page_text:
        print("Processing Insurance PDF (Shreyash)...")
        return process_insurance_pdf_shreyash(pdf_path)
    elif "The Postal Address of your SBI General Branch" in first_page_text:
        print("Processing Insurance PDF (SBI)...")
        return process_insurance_pdf_sbi(pdf_path)
    else:
        print("Unknown PDF format.")
        return None


def merge_dicts_based_on_key(existing_data, new_data, key):
    """
    Merges two dictionaries based on the value of a specific key. If the key value matches,
    it combines the data into a single dictionary, keeping non-null values from both.
    
    Args:
    - existing_data (dict): Existing dictionary to compare with.
    - new_data (dict): New dictionary to merge.
    - key (str): The key to compare values for merging.
    
    Returns:
    - dict: Merged dictionary.
    """
    for k, v in new_data.items():
        if pd.notna(v) and (k not in existing_data or pd.isna(existing_data[k])):
            existing_data[k] = v
    return existing_data

def save_to_excel(data_list, excel_path):
    """
    Save data to an Excel file, merging all information into a single row if the 'Chassis Number' matches.
    
    Args:
    - data_list (list of dict): List of dictionaries containing data to save.
    - excel_path (str): Path to the Excel file.
    """
    # Convert the new data to a DataFrame
    new_data = pd.DataFrame(data_list)

    # Ensure 'Chassis Number' is treated as a unique key
    if 'Chassis Number' not in new_data.columns:
        raise ValueError("The key column 'Chassis Number' is missing in the data.")

    # Check if the Excel file exists
    if os.path.exists(excel_path):
        # Load the existing data
        existing_data = pd.read_excel(excel_path)

        # Ensure both DataFrames have the same columns
        combined_columns = set(existing_data.columns).union(set(new_data.columns))
        existing_data = existing_data.reindex(columns=combined_columns)
        new_data = new_data.reindex(columns=combined_columns)

        # Merge the data row by row
        for _, new_row in new_data.iterrows():
            if new_row['Chassis Number'] in existing_data['Chassis Number'].values:
                # Find the index of the matching row
                idx = existing_data.loc[existing_data['Chassis Number'] == new_row['Chassis Number']].index[0]

                # Update the existing row with new non-null values
                for col in new_data.columns:
                    if pd.notna(new_row[col]):
                        existing_data.at[idx, col] = new_row[col]
            else:
                # Append new row if 'Chassis Number' is not found
                existing_data = pd.concat([existing_data, pd.DataFrame([new_row])], ignore_index=True)
    else:
        # If the file does not exist, use the new data as the initial DataFrame
        existing_data = new_data

    # Save the updated data back to Excel
    try:
        existing_data.to_excel(excel_path, index=False)
        print(f"Data saved successfully to {excel_path}")
    except Exception as e:
        print(f"Failed to save data to Excel: {e}")

# Function to process PDFs in a folder and write all data to Excel
def process_pdfs_in_folder(folder_path, excel_path):
    files = os.listdir(folder_path)
    pdf_files = [f for f in files if f.lower().endswith('.pdf')]

    all_extracted_data = []  # List to store data from all PDFs

    for pdf_file in pdf_files:
        pdf_path = os.path.join(folder_path, pdf_file)
        try:
            extracted_data = process_pdf_based_on_type(pdf_path)  # Assume this function extracts data as a dict
            if extracted_data:
                print("\nExtracted Data:")
                for key, value in extracted_data.items():
                    print(f"{key}: {value}")

                # Check for existing data with the same value of the first key
                first_key = list(extracted_data.keys())[0]  # Get the first key
                existing_entry = next(
                    (row for row in all_extracted_data if row.get(first_key) == extracted_data[first_key]), None
                )

                if existing_entry:
                    # Merge the new data with the existing entry
                    merge_dicts_based_on_key(existing_entry, extracted_data, first_key)
                else:
                    # Append as a new entry if no matching key value is found
                    all_extracted_data.append(extracted_data)
                
                print("-" * 50)
            else:
                print(f"No data extracted from {pdf_path}.")
        except Exception as e:
            print(f"Error processing {pdf_path}: {e}")

    # Save all extracted data to the Excel file
    if all_extracted_data:
        save_to_excel(all_extracted_data, excel_path)
        #print(all_extracted_data)
    else:
        print("No data extracted from any PDFs.")

if __name__ == "__main__":
    folder_path = "C:\\Users\\welcome\\Documents\\Carrum"  # Replace with your folder path
    excel_path = "C:\\Users\\welcome\\Documents\\Carrum\\extracted_data_carrum.xlsx"  # Path to save the Excel file
    process_pdfs_in_folder(folder_path, excel_path)
# Out:
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB19421
# Color: Superior White-26U
# Place of Supply: TELANGANA(36)
# From: VARUN MOTORS PVT LTD
# Invoice No.: 12/VSL/24002577
# Invoice Date: 28/08/2024 04:34 PM
# Owner: M/S. CARRUM MOBILITY SOLUTIONS PVT LTD
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,58,500.00
# Discount: ₹83000.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C597750
# --------------------------------------------------
# Processing Insurance PDF (SBI)...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB19421
# Insurance Company: SBI General Insurance Company Limited
# Policy Number: 0000000040526381
# INSURED’S DECLARED VALUE (IDV): 530,575
# Insurance Premium: 22,194.00
# Start Date: 28/08/2024
# End Date: 27/08/2025
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB21380
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 2/VSL/24000618
# Invoice Date: 29/06/2024 09:41 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 6,41,500.00
# Discount: ₹0.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C601382
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB21380
# Insurance Company: Go Digit General Insurance Ltd
# Policy Number: D154235494
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 22009
# Start Date: 30-JUN-2024
# End Date: 29-JUN-2025
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB21391
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 2/VSL/24000614
# Invoice Date: 29/06/2024 09:24 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 6,41,500.00
# Discount: ₹0.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C601539
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB21391
# Insurance Company: Go Digit General Insurance Ltd
# Policy Number: D154234560
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 22009
# Start Date: 30-JUN-2024
# End Date: 29-JUN-2025
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB21432
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 2/VSL/24000612
# Invoice Date: 29/06/2024 09:20 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,48,001.00
# Discount: ₹93499.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C600263
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB21432
# Insurance Company: Go Digit General Insurance Ltd
# Policy Number: D154233800
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 22009
# Start Date: 30-JUN-2024
# End Date: 29-JUN-2025
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB21765
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 1/VSL/24000931
# Invoice Date: 29/06/2024 11:20 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 6,41,500.00
# Discount: ₹0.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C601246
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB21765
# Insurance Company: Go Digit General Insurance Ltd
# Policy Number: D154235059
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 22009
# Start Date: 30-JUN-2024
# End Date: 29-JUN-2025
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB21810
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 2/VSL/24000622
# Invoice Date: 29/06/2024 10:43 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 6,41,500.00
# Discount: ₹0.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C601376
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB21810
# Insurance Company: Go Digit General Insurance Ltd
# Policy Number: D154235515
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 22009
# Start Date: 30-JUN-2024
# End Date: 29-JUN-2025
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB21918
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 1/VSL/24000927
# Invoice Date: 29/06/2024 10:53 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 6,41,500.00
# Discount: ₹0.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C601596
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB21918
# Insurance Company: Go Digit General Insurance Ltd
# Policy Number: D154235270
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 22009
# Start Date: 30-JUN-2024
# End Date: 29-JUN-2025
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB22113
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 2/VSL/24000628
# Invoice Date: 29/06/2024 10:58 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 6,41,500.00
# Discount: ₹0.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C602336
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB22113
# Insurance Company: Go Digit General Insurance Ltd
# Policy Number: D154235682
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 22009
# Start Date: 30-JUN-2024
# End Date: 29-JUN-2025
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB22569
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 2/VSL/24000633
# Invoice Date: 29/06/2024 11:12 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,48,001.00
# Discount: ₹93499.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C602455
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB22569
# Insurance Company: Go Digit General Insurance Ltd
# Policy Number: D154235846
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 22009
# Start Date: 30-JUN-2024
# End Date: 29-JUN-2025
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB23008
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 2/VSL/24000626
# Invoice Date: 29/06/2024 10:53 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 6,41,500.00
# Discount: ₹0.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C603187
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB23008
# Insurance Company: Go Digit General Insurance Ltd
# Policy Number: D154235654
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 22009
# Start Date: 30-JUN-2024
# End Date: 29-JUN-2025
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB30324
# Color: Superior White-26U
# Place of Supply: TELANGANA(36)
# From: VARUN MOTORS PVT LTD
# Invoice No.: 12/VSL/24002553
# Invoice Date: 28/08/2024 02:55 PM
# Owner: M/S. CARRUM MOBILITY SOLUTIONS PVT LTD
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,58,500.00
# Discount: ₹83000.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C613908
# --------------------------------------------------
# Processing Insurance PDF (SBI)...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB30324
# Insurance Company: SBI General Insurance Company Limited
# Policy Number: 0000000040527221
# INSURED’S DECLARED VALUE (IDV): 530,575
# Insurance Premium: 22,194.00
# Start Date: 28/08/2024
# End Date: 27/08/2025
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB31597
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 2/VSL/24001104
# Invoice Date: 31/07/2024 08:34 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,48,002.00
# Discount: ₹93498.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C616602
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB31597
# Insurance Company: Go Digit General Insurance Ltd
# Policy Number: D158999638
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 20950
# Start Date: 31-JUL-2024
# End Date: 30-JUL-2025
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB33556
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 2/VSL/24001106
# Invoice Date: 31/07/2024 08:38 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,48,002.00
# Discount: ₹93498.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C619581
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB33556
# Insurance Company: Go Digit General Insurance Ltd
# Policy Number: D158999607
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 20950
# Start Date: 31-JUL-2024
# End Date: 30-JUL-2025
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB36609
# Color: Superior White-26U
# Place of Supply: TELANGANA(36)
# From: VARUN MOTORS PVT LTD
# Invoice No.: 12/VSL/24002534
# Invoice Date: 27/08/2024 10:47 PM
# Owner: M/S. CARRUM MOBILITY SOLUTIONS PVT LTD
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,58,500.00
# Discount: ₹83000.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C624099
# --------------------------------------------------
# Processing Insurance PDF (SBI)...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB36609
# Insurance Company: SBI General Insurance Company Limited
# Policy Number: 0000000040529253
# INSURED’S DECLARED VALUE (IDV): 530,575
# Insurance Premium: 22,194.00
# Start Date: 28/08/2024
# End Date: 27/08/2025
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB36763
# Color: Superior White-26U
# Place of Supply: TELANGANA(36)
# From: VARUN MOTORS PVT LTD
# Invoice No.: 12/VSL/24002529
# Invoice Date: 27/08/2024 09:31 PM
# Owner: M/S. CARRUM MOBILITY SOLUTIONS PVT LTD
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,58,500.00
# Discount: ₹83000.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C624527
# --------------------------------------------------
# Processing Insurance PDF (SBI)...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB36763
# Insurance Company: SBI General Insurance Company Limited
# Policy Number: 0000000040528384
# INSURED’S DECLARED VALUE (IDV): 530,575
# Insurance Premium: 22,194.00
# Start Date: 28/08/2024
# End Date: 27/08/2025
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB39281
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 1/VSL/24001340
# Invoice Date: 10/08/2024 03:19 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,48,000.00
# Discount: ₹93500.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C626687
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB39281
# Insurance Company: Go Digit General Insurance Ltd
# Policy Number: D160097683
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 22007
# Start Date: 10-AUG-2024
# End Date: 09-AUG-2025
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB39495
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 2/VSL/24001165
# Invoice Date: 13/08/2024 01:26 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,48,000.00
# Discount: ₹93500.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C626960
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB39495
# Insurance Company: Go Digit General Insurance Ltd
# Policy Number: D160680434
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 20950
# Start Date: 14-AUG-2024
# End Date: 13-AUG-2025
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB39753
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 1/VSL/24001338
# Invoice Date: 10/08/2024 03:14 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,48,000.00
# Discount: ₹93500.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C627530
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB39753
# Insurance Company: Go Digit General Insurance Ltd
# Policy Number: D160096884
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 22009
# Start Date: 10-AUG-2024
# End Date: 09-AUG-2025
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB39918
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 1/VSL/24001339
# Invoice Date: 10/08/2024 03:16 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,48,000.00
# Discount: ₹93500.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C627391
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB39918
# Insurance Company: Go Digit General Insurance Ltd
# Policy Number: D160097343
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 22009
# Start Date: 10-AUG-2024
# End Date: 09-AUG-2025
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB40274
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 2/VSL/24001160
# Invoice Date: 13/08/2024 01:03 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,48,000.00
# Discount: ₹93500.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C628938
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB40274
# Insurance Company: Go Digit General Insurance Ltd
# Policy Number: D160680924
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 20950
# Start Date: 14-AUG-2024
# End Date: 13-AUG-2025
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB40585
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 2/VSL/24001166
# Invoice Date: 13/08/2024 01:31 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,48,000.00
# Discount: ₹93500.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C628530
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB40585
# Insurance Company: Go Digit General Insurance Ltd
# Policy Number: D160680726
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 20950
# Start Date: 14-AUG-2024
# End Date: 13-AUG-2025
# --------------------------------------------------
# Data saved successfully to C:\Users\welcome\Documents\Carrum\extracted_data_carrum.xlsx

# %% [markdown]
# # Complete Code with Automation(Screenshots)

# %%
import pytesseract
from PIL import Image
import re
import os
import pandas as pd

# Specify the path to the Tesseract executable
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def extract_text_from_image(image_path):
    """
    Extract text from an image using Tesseract OCR.
    
    Args:
        image_path (str): Path to the image file.
        
    Returns:
        str: Extracted text from the image.
    """
    try:
        image = Image.open(image_path)
        text = pytesseract.image_to_string(image)
        return text
    except Exception as e:
        return f"Error: {e}"

def extract_registration_date(text):
    """
    Extract the last date format from a line containing 'Date Of Registration'.
    
    Args:
        text (str): Input text containing 'Date Of Registration'.
        
    Returns:
        str: Extracted registration date or 'Not Found'.
    """
    # Split the text into lines
    lines = text.splitlines()
    for line in lines:
        if "Date Of Registration" in line:
            # Debugging: Print the matching line
            #print(f"Debug Line: {line}")
            # Regex to capture the last date-like pattern in the line
            pattern = r"(\d{1,2}/\d{1,2}/\d{4})$"
            match = re.search(pattern, line)
            if match:
                return match.group(1).strip()

    # Fallback: Search all lines for any date format
    fallback_pattern = r"(\d{1,2}/\d{1,2}/\d{4})"
    all_dates = re.findall(fallback_pattern, text)
    if all_dates:
        return all_dates[-1]  # Return the last found date
    return "Not Found"

def extract_field_values(text):
    """
    Extract specific field values from the OCR text using patterns.
    
    Args:
        text (str): Extracted text from the image.
        
    Returns:
        dict: A dictionary containing extracted field values.
    """
    try:
        patterns = {
            "Chassis Number": r"Enter Search Element:\*\s*\|\s*([A-Z0-9]+)",
            "Registration Number": r"Registration No:?[\|]?\s*([A-Z0-9]+)\s*Fuel Type:",
            "Mfg. Year": r"Mfg\. Year:\s*\|?\s*([0-9/]+)",
        }
        extracted_values = {}
        for field, pattern in patterns.items():
            match = re.search(pattern, text)
            extracted_values[field] = match.group(1) if match else "Not Found"

        # Extract Registration Date using a dedicated function
        extracted_values["Registration Date"] = extract_registration_date(text)
        return extracted_values
    except Exception as e:
        return {"Error": str(e)}

def save_to_excel(data_list, excel_path):
    """
    Save data to an Excel file, merging all information into a single row if the 'Chassis Number' matches.
    
    Args:
        data_list (list of dict): List of dictionaries containing data to save.
        excel_path (str): Path to the Excel file.
    """
    new_data = pd.DataFrame(data_list)

    if 'Chassis Number' not in new_data.columns:
        raise ValueError("The key column 'Chassis Number' is missing in the data.")

    if os.path.exists(excel_path):
        existing_data = pd.read_excel(excel_path)

        combined_columns = set(existing_data.columns).union(set(new_data.columns))
        existing_data = existing_data.reindex(columns=combined_columns)
        new_data = new_data.reindex(columns=combined_columns)

        for _, new_row in new_data.iterrows():
            if new_row['Chassis Number'] in existing_data['Chassis Number'].values:
                idx = existing_data.loc[existing_data['Chassis Number'] == new_row['Chassis Number']].index[0]
                for col in new_data.columns:
                    if pd.notna(new_row[col]):
                        existing_data.at[idx, col] = new_row[col]
            else:
                existing_data = pd.concat([existing_data, pd.DataFrame([new_row])], ignore_index=True)
    else:
        existing_data = new_data

    try:
        existing_data.to_excel(excel_path, index=False)
        print(f"Data saved successfully to {excel_path}")
    except Exception as e:
        print(f"Failed to save data to Excel: {e}")

def process_folder(folder_path, excel_path):
    """
    Process all images in a given folder and extract field values.
    
    Args:
        folder_path (str): Path to the folder containing images.
        excel_path (str): Path to the Excel file for saving data.
    """
    valid_extensions = {".jpg", ".jpeg", ".png", ".tiff", ".bmp", ".gif"}
    data_list = []

    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        if os.path.isfile(file_path) and os.path.splitext(file_name.lower())[1] in valid_extensions:
            print(f"\nProcessing: {file_name}")
            extracted_text = extract_text_from_image(file_path)
            print(f"Extracted OCR Text:\n{extracted_text}")  # Debugging: Print the OCR text
            field_values = extract_field_values(extracted_text)
            data_list.append(field_values)
        else:
            continue
            print(f"Skipping non-image file: {file_name}")

    if data_list:
        save_to_excel(data_list, excel_path)

# Path to the folder containing images
folder_path = "C:\\Users\\welcome\\Documents\\Carrum\\"
excel_path = r"C:\Users\welcome\Documents\Carrum\extracted_data_carrum.xlsx"

# Process the folder and save the data to Excel
process_folder(folder_path, excel_path)
Mth. Yr. of Mfg: 09/09/2024
# Out:
# Processing: MA3JMTB1SRFB21380 RC.png
# Extracted OCR Text:
# Vehicle Registration Search
#
# Select Search Element:* | CHASSIS NO. “
# Enter Search Element:* | MA3JMTB1SRFB21380
# 585890
#
# 585890 +>
#
# Captcha :*
#
# Registration No:|TG0O7T3914 Fuel Type:|CNG PETROL
# Owner Name:|CARRUM MOBILITY SOLU Vehicle Color:|SUPERIOR WHITE,
# Vehicle Class:IMOTOR CAB Maker's Name:|MARUTI SUZUKI INDIA LTD.,
# Mfg. Year:|06/06/2024 Maker's Class|MARUT! TOUR H3 CNG 1L 5MT BSVI-PH2}
# Engine No:|K10CNC6XXXXX Date Of Registration:|20/07/2024
# Chassis No:IMA3JMTB1SRFBXXXXX Financier: SUNDARAM FINANCE LIMITED
# Prev Registration No:|TO724DLXXXXX Registration AuthorityRTA RANGAREDDY
# [Harvester Chassis No: Status/ACTIVE
#
#
#
# Processing: MA3JMTB1SRFB21391 RC.png
# Extracted OCR Text:
# Vehicle Registration Search
#
# Select Search Element:* | CHASSIS NO. “
# Enter Search Element:* | MA3JMTB1SRFB21391
# 585890
#
# 585890 +>
#
# Captcha :*
#
# Registration No:|TG0O7T3923 Fuel Type:|CNG PETROL
# Owner Name:|CARRUM MOBILITY SOLU Vehicle Color:|SUPERIOR WHITE,
# Vehicle Class:IMOTOR CAB Maker's Name:|MARUTI SUZUKI INDIA LTD.,
# Mfg. Year:|06/06/2024 Maker's Class|MARUT! TOUR H3 CNG 1L 5MT BSVI-PH2}
# Engine No:|K10CNC6XXXXX Date Of Registration:|20/07/2024
# Chassis No:IMA3JMTB1SRFBXXXXX Financier: SUNDARAM FINANCE LIMITED
# Prev Registration No:|TO724DLXXXXX Registration AuthorityRTA RANGAREDDY
# [Harvester Chassis No: Status/ACTIVE
#
#
#
# Processing: MA3JMTB1SRFB21765 RC.png
# Extracted OCR Text:
# Vehicle Registration Search
#
# Select Search Element:* | CHASSIS NO. “
# Enter Search Element:* | MA3JMTB1SRFB21765
# 585890
#
# 585890 +>
#
# Captcha :*
#
# Registration No:|TGO7T3915 Fuel Type:|CNG PETROL
# Owner Name:|CARRUM MOBILITY SOLU Vehicle Color:|SUPERIOR WHITE,
# Vehicle Class:IMOTOR CAB Maker's Name:|MARUTI SUZUKI INDIA LTD.,
# Mfg. Year:|06/06/2024 Maker's Class|MARUT! TOUR H3 CNG 1L 5MT BSVI-PH2}
# Engine No:|K10CNC6XXXXX Date Of Registration:|20/07/2024
# Chassis No:IMA3JMTB1SRFBXXXXX Financier: SUNDARAM FINANCE LIMITED
# Prev Registration No:|TO724DLXXXXX Registration AuthorityRTA RANGAREDDY
# [Harvester Chassis No: Status/ACTIVE
#
#
#
# Processing: MA3JMTB1SRFB21810 RC.png
# Extracted OCR Text:
# Vehicle Registration Search
#
# Select Search Element:* | CHASSIS NO. “
# Enter Search Element:* | MA3JMTB1SRFB21810
# 688970
#
# 688970 +>
#
# Captcha :*
#
# Registration No:|TGO7T3911 Fuel Type:|CNG PETROL
# Owner Name:|CARRUM MOBILITY SOLU Vehicle Color:|SUPERIOR WHITE,
# Vehicle Class:IMOTOR CAB Maker's Name:|MARUTI SUZUKI INDIA LTD.,
# Mfg. Year:|06/06/2024 Maker's Class|MARUT! TOUR H3 CNG 1L 5MT BSVI-PH2}
# Engine No:|K10CNC6XXXXX Date Of Registration:|20/07/2024
# Chassis No:IMA3JMTB1SRFBXXXXX Financier: SUNDARAM FINANCE LIMITED
# Prev Registration No:|TO724DLXXXXX Registration AuthorityRTA RANGAREDDY
# [Harvester Chassis No: Status/ACTIVE
#
#
#
# Processing: MA3JMTB1SRFB21918 RC.png
# Extracted OCR Text:
# Vehicle Registration Search
#
# Select Search Element:* | CHASSIS NO. “
# Enter Search Element:* | MA3JMTB1SRFB21918
# 585890
#
# 585890 +>
#
# Captcha :*
#
# Registration No:|TG0O7T3917 Fuel Type:|CNG PETROL
# Owner Name:|CARRUM MOBILITY SOLU Vehicle Color:|SUPERIOR WHITE,
# Vehicle Class:IMOTOR CAB Maker's Name:|MARUTI SUZUKI INDIA LTD.,
# Mfg. Year:|06/06/2024 Maker's Class|MARUT! TOUR H3 CNG 1L 5MT BSVI-PH2}
# Engine No:|K10CNC6XXXXX Date Of Registration:|20/07/2024
# Chassis No:IMA3JMTB1SRFBXXXXX Financier: SUNDARAM FINANCE LIMITED
# Prev Registration No:|TO724DLXXXXX Registration AuthorityRTA RANGAREDDY
# [Harvester Chassis No: Status/ACTIVE
#
#
#
# Processing: MA3JMTB1SRFB22113 RC.png
# Extracted OCR Text:
# Vehicle Registration Search
#
# Select Search Element:* | CHASSIS NO. “
# Enter Search Element:* | MA3JMTB1SRFB22113
# 906798
#
# 906798 +>
#
# Captcha :*
#
# Registration No:|TGO7T3925 Fuel Type:|CNG PETROL
# Owner Name:|CARRUM MOBILITY SOLU Vehicle Color:|SUPERIOR WHITE,
# Vehicle Class:IMOTOR CAB Maker's Name:|MARUTI SUZUKI INDIA LTD.,
# Mfg. Year:|06/06/2024 Maker's Class|MARUT! TOUR H3 CNG 1L 5MT BSVI-PH2}
# Engine No:|K10CNC6XXXXX Date Of Registration:|20/07/2024
# Chassis No:IMA3JMTB1SRFBXXXXX Financier: SUNDARAM FINANCE LIMITED
# Prev Registration No:|TO724DLXXXXX Registration AuthorityRTA RANGAREDDY
# [Harvester Chassis No: Status/ACTIVE
#
#
#
# Processing: MA3JMTB1SRFB23008 RC.png
# Extracted OCR Text:
# Vehicle Registration Search
#
# Select Search Element:* | CHASSIS NO. “
# Enter Search Element:* | MA3JMTB1SRFB23008
# 688970
#
# 688970 +>
#
# Captcha :*
#
# Registration No:|TG0O7T3913 Fuel Type:|CNG PETROL
# Owner Name:|CARRUM MOBILITY SOLU Vehicle Color:|SUPERIOR WHITE,
# Vehicle Class:IMOTOR CAB Maker's Name:|MARUTI SUZUKI INDIA LTD.,
# Mfg. Year:|06/06/2024 Maker's Class|MARUT! TOUR H3 CNG 1L 5MT BSVI-PH2}
# Engine No:|K10CNC6XXXXX Date Of Registration:|20/07/2024
# Chassis No:IMA3JMTB1SRFBXXXXX Financier: SUNDARAM FINANCE LIMITED
# Prev Registration No:|TO724DLXXXXX Registration AuthorityRTA RANGAREDDY
# [Harvester Chassis No: Status/ACTIVE
#
#
#
# Processing: WhatsApp Image 2024-11-29 at 14.58.16_849056a5.jpg
# Extracted OCR Text:
# Vehicle Registration Search
#
# Select Search Element:* | CHASSIS NO. Ee
# Enter Search Element:* | MA3JMTB1SRFB18876
# 322156
#
# 322456 +4
#
# Captcha :*
#
# Registration No:TGO7T5651 Fuel Type:|CNG PETROL
# Owner Name:ICARRUM MOBILITY SOLU Vehicle Color:|SUPERIOR WHITE.
# Vehicle Class:|MOTOR CAB Maker's Name:/MARUTI SUZUKI INDIA LTD.,
# Mfg. Year:|06/06/2024 Maker's Class|MARUT! TOUR H3 CNG 1L 5MT BSVI-PH2|
# Engine No:iK10CNC5XXXXX Date Of Registration:02/09/2024
# Chassis No:|MA3JMTB1SRFBXXXXX Financier:|ORIX LEAISNG& FIN SER IND LTD
# Prev Registration No:|TGOQHTXXXXX Registration AuthorityRTA RANGAREDDY
# [Harvester Chassis No: Status:/ACTIVE
#
#
#
# Processing: WhatsApp Image 2024-11-29 at 14.58.52_a0282b93.jpg
# Extracted OCR Text:
# Vehicle Registration Search
#
# Select Search Element:* | CHASSIS NO. ¥
# Enter Search Element:* | MA3JMTB1SRFB18866
# 322156
#
# 322456 +
#
# Captcha :*
#
# Registration No:|TGO7T5655 Fuel Type:|CNG PETROL
# Owner Name:ICARRUM MOBILITY SOLU Vehicle Color:|SUPERIOR WHITE.
# Vehicle Class:IMOTOR CAB Maker's Name:/MARUTI SUZUKI INDIA LTD.,
# Mfg. Year:|06/06/2024 Maker's Class|MARUTI TOUR H3 CNG 1L 5MT BSVI-PH2
# Engine No:IK10CNCSXXXXX Date Of Registration:02/09/2024
# Chassis No:|MA3JMTB1SRFBXXXXX Financier:|ORIX LEAISNG& FIN SER IND LTD
# Prev Registration No:|TGOQHTXXXXX Registration AuthorityRTA RANGAREDDY
# [Harvester Chassis No: Status:ACTIVE
#
#
#
# Processing: WhatsApp Image 2024-11-29 at 15.00.06_4ec87ba9.jpg
# Extracted OCR Text:
# Vehicle Registration Search
#
# Select Search Element:* | CHASSIS NO. Y
# Enter Search Element:* | MA3JMTB1SRFB18918
# 322156
#
# 322456 +
# [cer pata] [CLEAR |
#
# Captcha :*
#
# Registration No:|TGO7T5657 Fuel Type:|CNG PETROL
# Owner Name:ICARRUM MOBILITY SOLU Vehicle Color:|SUPERIOR WHITE.
# Vehicle Class:|MOTOR CAB Maker's Name:/MARUTI SUZUKI INDIA LTD.,
# Mfg. Year:06/06/2024 Maker's Class|MARUT! TOUR H3 CNG 1L 5MT BSVI-PH2}
# Engine No:IK10CNC5XXXXX Date Of Registration:02/09/2024
# Chassis No:|MA3JMTB1SRFBXXXXX Financier:|ORIX LEAISNG& FIN SER IND LTD
# Prev Registration No:|TGO9HTXXXXX Registration AuthorityRTA RANGAREDDY
# [Harvester Chassis No: Status:ACTIVE
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.00_69bcefd5.jpg
# Extracted OCR Text:
# (>) wallet
#
# Duorre gebds dare wD
#
# OF REGISTRAION
#
# Regn, Number : TGO7T8367
# _CARRUM MOBILITY
# Regd. Owner “SOLU
# = _F NO 504 ANURAG TWRS
# & Address “100 FT RD, BEST
# _MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVI-PH2
# Vehicle Class : Motor Cab
# Mth. Yr. of Mfg 10/10/2024
# Fucl Used : CNG PETROL
#
# Chassis Number MA3JMTBISRKB85639
#
# Engine Number K10CNC702554
# Cubuie Capacity
#
# Wheel Base
#
# Seating Capacity +5
#
# Unladen Weight
#
# Color : SUPERIOR WHITE
#
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Date of Registration
# Regn. Valid Upto
# Tax
#
# Hypothecated To
#
# sult
#
# Registering Authority
#
# Signature of the Owner RTKRARGARERDS
#
# INSURANCE
#
# PTAILS
#
# Vehicle Number AEGORESSC2
#
# SHARE THIS CARD DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.06_9908b443.jpg
# Extracted OCR Text:
# (>) M-wallet
#
# Duorre gebdy dare wD
#
# OF REGISTRAION
#
# Regn, Number : TGO7T8366
# _CARRUM MOBILITY
# Regd. Owner “SOLU
# _F NO 504 ANURAG TWRS
# Address “100 FT RD, BEST
# _MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVI-PH2
# Vehicle Class : Motor Cab
# Mth. Yr. of Mfg 10/10/2024
# Fucl Used : CNG PETROL
#
# Chassis Number  MA3JMTBISRKB85589
#
# Engine Number K10CNC702543
# Cubuie Capacity
#
# Wheel Base
#
# Seating Capacity +5
#
# Unladen Weight
#
# Color : SUPERIOR WHITE
#
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Date of Registration
# Regn. Valid Upto
# Tax
#
# Hypothecated To
#
# s
#
# sult
#
# Registering Authority
#
# Signature of the Owner RTMRARGARERDS
#
# INSURANCE
#
# PTAILS
#
# Vehicle Number BEGORES366
#
# SHARE THIS CARD DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.20_243f958d.jpg
# Extracted OCR Text:
# ()M-Wallet
#
# Duorre gebds dare wD
#
# OF REGISTRAION
#
# Chassis Number
# Engine Number
# Cubuie Capacity
# Wheel Base
# Seating Capacity
# Unladen Weight
# Color
#
# Date of Registration
#
# Regn. Valid Upto
#
# Tax
#
# Regn, Number : TG07T8373
# . CARRUM MOBILITY
# Regd. Owner “SOLU
# FNO 504 ANURAG
# Address : TOWERS 100 FT RD, BESI
# MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVL-PH2
# Vehicle Class : Motor Cab
# Mth. Yr. of Mfg 09/09/2024
# Fuel Used : CNG PETROL
# : MA3JMTBISRJB71501
# K10CNC677110
#
# : SUPERIOR WHITE
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Hypothecated To
#
# 2
#
# Signature of the Owner
#
# Vehicle Number
#
# sult
#
# Registering Authority
# RTA RANGAREDDY
#
# INSURANCE DETAILS
#
# PRGORESI73
#
# DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.21_9972adf7.jpg
# Extracted OCR Text:
# ()M-Wallet
#
# Duorre gebds dare wD
#
# OF REGISTRAION
#
# Regn, Number : TG07T8377
# _CARRUM MOBILITY
# Regd. Owner “SOLU
# _FNO 504 ANURAG
# Address “ TOWERS 100 FT RD, BESI
# _MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVI-PH2
# Vehicle Class : Motor Cab
# Mth. Yr. of Mfg + 10/10/2024
# Fucl Used : CNG PETROL
#
# Chassis Number  MA3JMTB1SRKB85798
#
# Engine Number K10CNC702851
# Cubuie Capacity
#
# Wheel Base
#
# Seating Capacity +5
#
# Unladen Weight
#
# Color : SUPERIOR WHITE
#
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Date of Registration
# Regn. Valid Upto
# Tax
#
# Hypothecated To
#
# =
# sult
#
# Registering Authority
#
# Signature of the Owner mrkmanGancene
#
# INSURANCE
#
# TAILS
#
# Vehicle Number PEGORESI77
#
# DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.21_d78d8a1a.jpg
# Extracted OCR Text:
# ()M-Wallet
#
# Duorre gebdy dare wD
#
# OF REGISTRAION
#
# Ty
#
# Chassis Number
#
# Engine Number
# Cubuie Capacity
# Wheel Base
# Seating Capacity
# Unladen Weight
# Color
#
# Date of Registration
#
# Regn. Valid Upto
#
# Tax
#
# Hypothecated To
#
# Signature of the Owner
#
# Vehicle Number
#
# Regn. Number : TGO7T8376
# . CARRUM MOBILITY
# Regd. Owner “SOLU
# FNO 504 ANURAG
# Address : TOWERS 100 FT RD, BESI
# MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVL-PH2
# Vehicle Class : Motor Cab
# Mth. Yr. of Mfg: 10/10/2024
# Fuel Used : CNG PETROL
# : MA3JMTBISRKB75444
# K10CNC684148
#
# : SUPERIOR WHITE
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# sult
#
# Registering Authority
# RTA RANGAREDDY
#
# INSURANCE
#
# TAILS
#
# PEGORESI76
#
# DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.22_20071314.jpg
# Extracted OCR Text:
# ()M-Wallet
#
# Duorre Qebdy dare wD
#
# OF REGISTRAION
#
# Rega, Number : TGO7T8375
# _CARRUM MOBILITY
# Regd. Owner “SOLU
# _FNO 504 ANURAG
# Address “ TOWERS 100 FT RD, BESI
# _MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVI-PH2
# Vehicle Class : Motor Cab
# Mth. Yr. of Mfg + 10/10/2024
# Fucl Used : CNG PETROL
#
# Chassis Number MA3JMTB1SRKB85921
#
# Engine Number K10CNC703074
# Cubuie Capacity
#
# Wheel Base
#
# Seating Capacity +5
#
# Unladen Weight
#
# Color : SUPERIOR WHITE
#
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Date of Registration
# Regn. Valid Upto
# Tax
#
# Hypothecated To
#
# FZ
#
# sult
#
# Registering Authority
#
# Signature of the Owner mrkmanGancene
#
# INSURANCE
#
# TAILS
#
# Vehicle Number PEGORESI25
#
# DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.23_15460e48.jpg
# Extracted OCR Text:
# ()M-Wallet
#
# Duorre gebds dare wD
#
# OF REGISTRAION
#
# Regn, Number : TGO7T8374
# _CARRUM MOBILITY
# Regd. Owner “SOLU
# _FNO 504 ANURAG
# Address “ TOWERS 100 FT RD, BESI
# _MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVI-PH2
# Vehicle Class : Motor Cab
# Mth. Ye. of Mfg + 10/10/2024
# Fucl Used : CNG PETROL
#
# Chassis Number  MA3JMTBISRKB85899
#
# Engine Number K10CNC702961
# Cubuic Capacity
#
# Wheel Base
#
# Seating Capacity 5
#
# Unladen Weight
#
# Color : SUPERIOR WHITE
#
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Date of Registration
# Regn. Valid Upto
# Tax
#
# Hypothecated To
#
# sult
#
# Registering Authority
#
# Signature of the Owner mrkmanGancene
#
# INSURANCE
#
# PTAILS
#
# Vehicle Number PEGORESI72
#
# DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.33_8a6ecdd3.jpg
# Extracted OCR Text:
# ()M-Wallet
#
# Duorre Qebdy dare wD
#
# OF REGISTRAION
#
# Rega, Number : TGO7T8378
# _CARRUM MOBILITY
# Regd. Owner “SOLU
# _FNO 504 ANURAG
# Address “ TOWERS 100 FT RD, BESI
# _MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVI-PH2
# Vehicle Class : Motor Cab
# Mth. Yr. of Mfg: 09/09/2024
# Fucl Used : CNG PETROL
#
# Chassis Number MA3JMTB1SRJB73518
#
# Engine Number K10CNC680751
# Cubuie Capacity
#
# Wheel Base
#
# Seating Capacity +5
#
# Unladen Weight
#
# Color : SUPERIOR WHITE
#
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Date of Registration
# Regn. Valid Upto
# Tax
#
# Hypothecated To
#
# =
#
# sult
#
# Registering Authority
#
# Signature of the Owner mrkmanGancene
#
# INSURANCE DETAILS
#
# Vehicle Number BEGORESI78
#
# DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.35_58c81630.jpg
# Extracted OCR Text:
# (_)M-Wallet
#
# Duorre gebds dare wD
#
# OF REGISTRAION
#
# ~
#
# Chassis Number
# Engine Number
# Cubuie Capacity
# Wheel Base
# Seating Capacity
# Unladen Weight
# Color
#
# Date of Registration
#
# Regn. Valid Upto
#
# Tax
#
# Regn, Number : TGO7T8380
# . CARRUM MOBILITY
# Regd. Owner “SOLU
# FNO 504 ANURAG
# Address e TOWERS 100 FT RD, BESI
# MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVL-PH2
# Vehicle Class : Motor Cab
# Mth. Yr. of Mfg 09/09/2024
# Fuel Used : CNG PETROL
# : MA3JMTB1SRJB72311
# K10CNC678370
#
# : SUPERIOR WHITE
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Hypothecated To
#
# =
#
# Signature of the Owner
#
# Vehicle Number
#
# sult
#
# Registering Authority
# RTA RANGAREDDY
#
# INSURANCE DETAILS
#
# BEGORESSa0
#
# DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.38_f6abbb70.jpg
# Extracted OCR Text:
# ()M-Wallet
#
# Duorre gebds dare wD
#
# OF REGISTRAION
#
# Regn, Number : TGO7T8381
# _CARRUM MOBILITY
# Regd. Owner “SOLU
# _FNO 504 ANURAG
# Address “ TOWERS 100 FT RD, BESI
# _MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVI-PH2
# Vehicle Class : Motor Cab
# Mth. Yr. of Mfg + 10/10/2024
# Fucl Used : CNG PETROL
#
# Chassis Number  MA3JMTBISRKB85840
#
# Engine Number K10CNC702944
# Cubuic Capacity
#
# Wheel Base
#
# Seating Capacity 5
#
# Unladen Weight
#
# Color : SUPERIOR WHITE
#
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Date of Registration
# Regn. Valid Upto
# Tax
#
# Hypothecated To
#
# sult
#
# Registering Authority
#
# Signature of the Owner mrkmanGancene
#
# INSURANCE
#
# PTAILS
#
# Vehicle Number ARGORESSa1
#
# DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.42_2a97fe9a.jpg
# Extracted OCR Text:
# ()M-Wallet
#
# Duorre gebdy dare wD
#
# OF REGISTRAION
#
# Regn, Number : TGO7T8382
# _CARRUM MOBILITY
# Regd. Owner “SOLU
# _FNO 504 ANURAG
# Address “ TOWERS 100 FT RD, BESI
# _MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVI-PH2
# Vehicle Class : Motor Cab
# Mth. Ye. of Mfg + 10/10/2024
# Fucl Used : CNG PETROL
#
# Chassis Number  MA3JMTBISRKB85620
#
# Engine Number K10CNC702550
# Cubuie Capacity
#
# Wheel Base
#
# Seating Capacity +5
#
# Unladen Weight
#
# Color : SUPERIOR WHITE
#
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Date of Registration
# Regn. Valid Upto
# Tax
#
# Hypothecated To
#
# -
# sult
#
# Registering Authority
#
# Signature of the Owner mrkmanGancene
#
# INSURANCE
#
# TAILS
#
# Vehicle Number BEGORES3#2
#
# DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.43_3c073698.jpg
# Extracted OCR Text:
# ()M-Wallet
#
# Duorre gebds dare wD
#
# OF REGISTRAION
#
# Regn, Number : TGO7T8386
# _CARRUM MOBILITY
# Regd. Owner “SOLU
# _FNO 504 ANURAG TWRS,
# Address “100 FT RD BESIDE
# _MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVI-PH2
# Vehicle Class : Motor Cab
# Mth. Yr. of Mfg: 09/09/2024
# Fucl Used : CNG PETROL
#
# Chassis Number: MA3JMTB1SRJB71942
#
# Engine Number K10CNC677800
# Cubuie Capacity
#
# Wheel Base
#
# Seating Capacity +5
#
# Unladen Weight
#
# Color : SUPERIOR WHITE
#
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Date of Registration
# Regn. Valid Upto
# Tax
#
# Hypothecated To
#
# : sult
#
# Registering Authority
#
# Signature of the Owner RTKRARGAREDDS
#
# INSURANCE DETAILS
#
# Vehicle Number BrGoRES3#6
#
# SHARE THIS CARD DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.50_a0510d9d.jpg
# Extracted OCR Text:
# ()M-Wallet
#
# Duorre gebds dare wD
#
# OF REGISTRAION
#
# Chassis Number
# Engine Number
# Cubuie Capacity
# Wheel Base
# Seating Capacity
# Unladen Weight
# Color
#
# Date of Registration
#
# Regn. Valid Upto
#
# Tax
#
# Regn, Number : TGO7T8385
# . CARRUM MOBILITY
# Regd. Owner “SOLU
# FNO 504 ANURAG TWRS,
# Address 5 100 FT RD BESIDE
# MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVL-PH2
# Vehicle Class : Motor Cab
# Mth. Yr. of Mfg: 09/09/2024
# Fuel Used : CNG PETROL
# : MA3JMTB1SRJB72001
# K10CNC677956
#
# : SUPERIOR WHITE
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Hypothecated To
#
# =
#
# Signature of the Owner
#
# Vehicle Number
#
# sult
#
# Registering Authority
# RTA RANGAREDDY
#
# INSURANCE DETAILS
#
# ARGORESS#5
#
# SHARE THIS CARD DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.10_f29b3bd8.jpg
# Extracted OCR Text:
# (>) M-wallet
#
# Duorre gebds dare wD
#
# OF REGISTRAION
#
# Rega, Number : TGO7T8383
# _CARRUM MOBILITY
# Regd. Owner “SOLU
# _FNO 504 ANURAG
# Address “ TOWERS 100 FT RD, BESI
# _MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVI-PH2
# Vehicle Class : Motor Cab
# Mth. Yr. of Mfg: 09/09/2024
# Fucl Used : CNG PETROL
#
# Chassis Number  MA3JMTB1SRJB73690
#
# Engine Number K10CNC681202
# Cubuie Capacity
#
# Wheel Base
#
# Seating Capacity +5
#
# Unladen Weight
#
# Color : SUPERIOR WHITE
#
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Date of Registration
# Regn. Valid Upto
# Tax
#
# Hypothecated To
#
# sult
#
# Registering Authority
#
# Signature of the Owner RTKRARGAREDDS
#
# INSURANCE DETAILS
#
# Vehicle Number PRGORESI83
#
# DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.12_d80e226c.jpg
# Extracted OCR Text:
# () wallet
#
# Duorre gebds dare wD
#
# OF REGISTRAION
#
# Regn, Number : TGO7T8384
# _CARRUM MOBILITY
# Regd. Owner “SOLU
# a _FNO 504 ANURAG
# r Address “ TOWERS 100 FT RD, BESI
# _MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVI-PH2
# Vehicle Class : Motor Cab
# Mth. Yr. of Mfg: 09/09/2024
# Fucl Used : CNG PETROL
#
# Chassis Number : MA3JMTB1SRJB72127
# Engine Number K10CNC678157
#
# Cubuie Capacity
#
# Wheel Base
#
# Seating Capacity +5
#
# Unladen Weight
#
# Color : SUPERIOR WHITE
#
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Date of Registration
# Regn. Valid Upto
# Tax
#
# Hypothecated To
# x
#
# sult
#
# Registering Authority
#
# Signature of the Owner RTKRARGAREDDS
#
# INSURANCE DETAILS
#
# Vehicle Number PEGORESS #2
#
# DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.12_ea00f9cf.jpg
# Extracted OCR Text:
# M- Wallet
#
# Govt OF Telangana Transport Dapare
#
# OF REGISTRAION
#
# Regn, Number : TGO7T8387
# _CARRUM MOBILITY
#
# Regd. Owner “SOLU
# _FNO 504 ANURAG TWRS,
#
# Address “100 FT RD BESIDE
# _MARUTI TOUR H3 CNG
#
# Maker's Class “IL SMT BSVI-PH2
#
# Vehicle Class : Motor Cab
#
# Mth. Yr. of Mfg: 09/09/2024
#
# Fucl Used : CNG PETROL
#
# Chassis Number  MA3JMTB1SRJB72046
#
# Engine Number K10CNC678030
# Cubuie Capacity
#
# Wheel Base
#
# Seating Capacity +5
#
# Unladen Weight
#
# Color : SUPERIOR WHITE
#
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Date of Registration
# Regn. Valid Upto
# Tax
#
# Hypothecated To
#
# . putt
#
# Registering Authority
#
# Signature of the Owner RTKRARGAREDDS
#
# INSURANCE
#
# PTAILS
#
# Vehicle Number PEGORESS37
#
# SHARE THIS CARD DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.15_c606bbf6.jpg
# Extracted OCR Text:
# M-Wallet
#
# Govt. Of Telangana Transport Deparme
# Duorre gebds dare wD
#
# OF REGISTRAION
#
# Regn, Number : TGO7T8363
# _CARRUM MOBILITY
# Regd. Owner “SOLU
# _FNO 504 ANURAG TWRS,
# Address “100 FT RD BESIDE
# _MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVI-PH2
# Vehicle Class : Motor Cab
# Mth. Yr. of Mfg + 10/10/2024
# Fucl Used : CNG PETROL
#
# Chassis Number  MA3JMTBISRKB85550
#
# Engine Number K10CNC702480
# Cubuie Capacity
#
# Wheel Base
#
# Seating Capacity +5
#
# Unladen Weight
#
# Color : SUPERIOR WHITE
#
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Date of Registration
# Regn. Valid Upto
# Tax
#
# Hypothecated To
#
# =
#
# sult
#
# Registering Authority
#
# Signature of the Owner RTKRARGAREDDS
#
# INSURANCE
#
# PTAILS
#
# Vehicle Number PEGORESS63
#
# SHARE THIS CARD DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.16_2ba9c88f.jpg
# Extracted OCR Text:
# ()M-wallet
#
# Duorre gebds dare wD
#
# OF REGISTRAION
#
# Regn. Number : TG07T8364
# _CARRUM MOBILITY
# Regd. Owner “SOLU
# _FNO 504 ANURAG TWRS,
# Address “100 FT RD BESIDE
# _MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVI-PH2
# Vehicle Class : Motor Cab
# Mth. Ye. of Mfg + 10/10/2024
# Fucl Used : CNG PETROL
#
# Chassis Number  MA3JMTB1SRKB85647
#
# Engine Number K10CNC702601
# Cubuie Capacity
#
# Wheel Base
#
# Seating Capacity +5
#
# Unladen Weight
#
# Color : SUPERIOR WHITE
#
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Date of Registration
# Regn. Valid Upto
# Tax
#
# Hypothecated To
#
# sult
#
# Registering Authority
#
# Signature of the Owner mrkmanGancene
#
# INSURANCE
#
# PTAILS
#
# Vehicle Number AEGORESS CR
#
# SHARE THIS CARD DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.16_da0bd9f7.jpg
# Extracted OCR Text:
# M-Wallet
#
# Govt. Of Telangana Transport Deparme
# Duorre gebds dare wD
#
# OF REGISTRAION
#
# Regn, Number : TGO7T8365
# _CARRUM MOBILITY
# Regd. Owner “SOLU
# _FNO 504 ANURAG TWRS,
# Address “100 FT RD BESIDE
# _MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVI-PH2
# Vehicle Class : Motor Cab
# Mth. Yr. of Mfg 10/10/2024
# Fucl Used : CNG PETROL
#
# Chassis Number  MA3JMTBISRKB85658
#
# Engine Number K10CNC702652
# Cubuie Capacity
#
# Wheel Base
#
# Seating Capacity +5
#
# Unladen Weight
#
# Color : SUPERIOR WHITE
#
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Date of Registration
# Regn. Valid Upto
# Tax
#
# Hypothecated To
#
# =
#
# sult
#
# Registering Authority
#
# Signature of the Owner RTMRARGARERDS
#
# INSURANCE
#
# PTAILS
#
# Vehicle Number PEGORESSES
#
# SHARE THIS CARD DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.17_a67969bd.jpg
# Extracted OCR Text:
# ()M-Wallet
#
# Duorre gebds dare wD
#
# OF REGISTRAION
#
# Chassis Number
#
# Engine Number
# Cubuie Capacity
# Wheel Base
# Seating Capacity
# Unladen Weight
# Color
#
# Date of Registration
#
# Regn. Valid Upto
#
# Tax
#
# Regn, Number : TGO7T8368
# . CARRUM MOBILITY
# Regd. Owner “SOLU
# F NO 504 ANURAG TWRS
# Address 5 100 FT RD, BEST
# MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVL-PH2
# Vehicle Class : Motor Cab
# Mth. Yr. of Mfg 09/09/2024
# Fuel Used : CNG PETROL
# : MA3JMTBISRJB72182
# K10CNC678210
#
# : SUPERIOR WHITE
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Hypothecated To
#
# x
#
# Signature of the Owner
#
# Vehicle Number
#
# sult
#
# Registering Authority
# RTA RANGAREDDY
#
# INSURANCE DETAILS
#
# AEGORESSEs
#
# SHARE THIS CARD DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.18_b03423b4.jpg
# Extracted OCR Text:
# (>) wallet
#
# Duorre gebds dare wD
#
# OF REGISTRAION
#
# Regn, Number : TGO7T8370
# _CARRUM MOBILITY
# Regd. Owner “SOLU
# _F NO 504 ANURAG TWRS
# Address “100 FT RD, BEST
# _MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVI-PH2
# Vehicle Class : Motor Cab
# Mth. Yr. of Mfg + 10/10/2024
# Fucl Used : CNG PETROL
#
# Chassis Number  MA3JMTB1SRKB85887
#
# Engine Number K10CNC701840
# Cubuie Capacity
#
# Wheel Base
#
# Seating Capacity +5
#
# Unladen Weight
#
# Color : SUPERIOR WHITE
#
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Date of Registration
# Regn. Valid Upto
# Tax
#
# Hypothecated To
#
# sult
#
# Registering Authority
#
# Signature of the Owner RTKRARGARERDS
#
# INSURANCE
#
# TAILS
#
# Vehicle Number AnGoREs370
#
# SHARE THIS CARD DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.19_0b2f0c91.jpg
# Extracted OCR Text:
# ()M-Wallet
#
# Duorre gebds dare wD
#
# OF REGISTRAION
#
# Chassis Number
# Engine Number
# Cubuie Capacity
# Wheel Base
# Seating Capacity
# Unladen Weight
# Color
#
# Date of Registration
#
# Regn. Valid Upto
#
# Tax
#
# Regn, Number : TG07T8372
# . CARRUM MOBILITY
# Regd. Owner “SOLU
# FNO 504 ANURAG TWRS,
# Address 5 100 FT RD BESIDE
# MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVL-PH2
# Vehicle Class : Motor Cab
# Mth. Yr. of Mfg: 09/09/2024
# Fuel Used : CNG PETROL
# : MA3JMTBISRJB72252
# K10CNC678267
#
# : SUPERIOR WHITE
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Hypothecated To
#
# ee)
#
# Signature of the Owner
#
# Vehicle Number
#
# sult
#
# Registering Authority
# RTA RANGAREDDY
#
# INSURANCE DETAILS
#
# PEGORES372
#
# SHARE THIS CARD DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.19_c8f14133.jpg
# Extracted OCR Text:
# (>) M-wallet
#
# Duorre gebds dare wD
#
# OF REGISTRAION
#
# Regn, Number : TG07T8371
# _CARRUM MOBILITY
# Regd. Owner “SOLU
# _F NO 504 ANURAG TWRS
# Address “100 FT RD, BEST
# _MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVI-PH2
# Vehicle Class : Motor Cab
# Mth. Ye. of Mfg + 10/10/2024
# Fucl Used : CNG PETROL
#
# Chassis Number: MA3JMTB1SRKB85779
#
# Engine Number K10CNC702804
# Cubuie Capacity
#
# Wheel Base
#
# Seating Capacity +5
#
# Unladen Weight
#
# Color : SUPERIOR WHITE
#
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Date of Registration
# Regn. Valid Upto
# Tax
#
# Hypothecated To
#
# sult
#
# Registering Authority
#
# Signature of the Owner RTMRARGARERDS
#
# INSURANCE
#
# PTAILS
#
# Vehicle Number BnGonEs374
#
# SHARE THIS CARD DELETE THIS CARD
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.20_2419b764.jpg
# Extracted OCR Text:
# 1:29)
#
# M-Wallet
#
# Govt. Of Telangana Transport Department
# Bvorre Qadey aver wa
#
# TELANGANA STATE TRANSPORT DEPARTMENT
#
# CERTIFICATE OF REGISTRAION
#
# Regn. Number : TGO7T8369
# _CARRUM MOBILITY
# Regd. Owner “SOLU
# _F NO 504 ANURAG TWRS
# Address *100 FT RD, BESI
# _MARUTI TOUR H3 CNG
# Maker's Class “1L SMT BSVI-PH2
# Vehicle Class : Motor Cab
# Mth. Yr. of Mfg 2 09/09/2024
# Fucl Used : CNG PETROL
#
# Chassis Number : MA3JMTBISRJB71971
#
# Engine Number : KIOCNC678016
# Cubuic Capacity 2998.0
# Wheel Base : 2435
# Seating Capacity :5
# Unladen Weight 910.0
# Color : SUPERIOR WHITE
# Date of Registration : 20/11/2024
# Regn. Valid Upto: 19/11/2026
# ‘Tax : 18/11/2036
# Hypothecated To
#
# =
#
# St
#
# Registering Authority
#
# Signat f the O
# BAR LOE CREE TIRES, RTA RANGAREDDY
#
# INSURANCE DETAILS
#
# Vehicle Number : TGO7T8369
#
# DELETE THIS CARD
#
#
# Processing: WhatsApp Image 2024-11-30 at 13.10.58_7068a1cc.jpg
# Extracted OCR Text:
# Vehicle Registration Search
#
# Select Search Element:* | CHASSIS NO. x
# Enter Search Element:* | MA3JMTB1SRGB30324
# 610686
#
# 774065 +
# [cer pata] — | CLEAR |
#
# Captcha :*
#
# Registration No:|TG0O7T5551 Fuel Type:;CNG PETROL
# Owner Name:ICARRUM MOBILITY SOLU) Vehicle Color:|SUPERIOR WHITE,
# Vehicle Class:IMOTOR CAB Maker's Name:|MARUT! SUZUKI INDIA LTD.,
# Mfg. Year:|07/07/2024 Maker's Class|MARUTI TOUR H3 CNG 1L 5MT BSVI-PH2)
# Engine No:|K10CNC6XXXXX Date Of Registration:/3 1/08/2024
# Chassis No:|MA3JMTB1SRGBXXXXX Financier:STATE BANK OF INDIA
# Prev Registration No:|TGOQHTXXXXX Registration AuthorityRTA RANGAREDDY
# [Harvester Chassis No: Status:/ACTIVE
#
#
#
# Processing: WhatsApp Image 2024-11-30 at 13.12.17_415afcd2.jpg
# Extracted OCR Text:
# Vehicle Registration Search
#
# Select Search Element:* | CHASSIS NO. BA
# Enter Search Element:* | MA3JMTB1SRFB19421
# 001674
#
# §74783 +
# GET DATA [ CLEAR |
#
# Captcha :*
#
# Registration No:TGO7T5552 Fuel Type:|CNG PETROL
# Owner Name:|CARRUM MOBILITY SOLU Vehicle Color:|SUPERIOR WHITE.
# Vehicle Class:IMOTOR CAB Maker's Name:/MARUTI SUZUKI INDIA LTD.,
# Mfg. Year:|06/06/2024 Maker's Class|MARUT! TOUR H3 CNG 1L 5MT BSVI-PH2)
# Engine No:|K10CNC5XXXXX Date Of Registration:/3 1/08/2024
# Chassis No:|MA3JMTB1SRFBXXXXX Financier:STATE BANK OF INDIA
# Prev Registration No:|TGOQHTXXXXX Registration AuthorityRTA RANGAREDDY
# [Harvester Chassis No: Status:ACTIVE
#
#
# Data saved successfully to C:\Users\welcome\Documents\Carrum\extracted_data_carrum.xlsx
# C:\Users\welcome\AppData\Local\Temp\ipykernel_10236\807312985.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'TG0O7T3914' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   existing_data.at[idx, col] = new_row[col]
# C:\Users\welcome\AppData\Local\Temp\ipykernel_10236\807312985.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '06/06/2024' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   existing_data.at[idx, col] = new_row[col]
# C:\Users\welcome\AppData\Local\Temp\ipykernel_10236\807312985.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '20/07/2024' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   existing_data.at[idx, col] = new_row[col]

# %% [markdown]
# # for Telangana Screenshot

# %%
import pytesseract
from PIL import Image
import os
import re

# Specify the path to the Tesseract executable
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# List of valid strings to check in the first line of text
VALID_STRINGS = [
    "M-Wallet", "(>) M-wallet", "()M-Wallet", "(>) wallet", "(>) M-wallet",
    "()M-Wallet", "(_)M-Wallet", "()M-Wallet", "()M-Wallet", "(>) M-wallet",
    "()M-Wallet", "()M-Wallet", "() wallet"
]

def extract_text_from_image(image_path):
    """
    Extract text from an image using Tesseract OCR.
    
    Args:
        image_path (str): Path to the image file.
        
    Returns:
        str: Extracted text from the image.
    """
    try:
        image = Image.open(image_path)
        text = pytesseract.image_to_string(image)
        return text
    except Exception as e:
        return f"Error: {e}"

def extract_field_values(text):
    """
    Extract specific field values from the OCR text using refined patterns.
    
    Args:
        text (str): Extracted text from the image.
        
    Returns:
        dict: A dictionary containing extracted field values.
    """
    try:
        # Define refined patterns for each field
        patterns = {
            "Chassis Number": r"Chassis Number[:\s]*([A-Z0-9]+)",
            "Registration Number": r"Reg[n|a]?[.,]?\s*Number[:\s]*(TG[A-Z0-9]+)",
            "Mfg. Year": r"(Mth[.\s]*.*?Mfg.*?(\d{2}/\d{2}/\d{4}))",
            "Registration Date": r"Color.*?\n.*?(\d{2}/\d{2}/\d{4})"
        }

        # Extract values
        extracted_values = {}
        for field, pattern in patterns.items():
            match = re.search(pattern, text, re.IGNORECASE | re.DOTALL)
            if field == "Mfg. Year" and match:
                # Extract the date from the matched line
                extracted_values[field] = match.group(2) if match else "Not Found"
            elif field == "Registration Date" and match:
                # Extract only the first valid date after "Color"
                date_match = re.search(r"\d{2}/\d{2}/\d{4}", match.group(1))
                extracted_values[field] = date_match.group(0) if date_match else "Not Found"
            else:
                extracted_values[field] = match.group(1) if match else "Not Found"
        
        return extracted_values
    except Exception as e:
        return {"Error": str(e)}

def process_folder(folder_path):
    """
    Process all images in a folder and print extracted details if the first line matches a valid string.
    
    Args:
        folder_path (str): Path to the folder containing images.
    """
    valid_extensions = {".jpg", ".jpeg"}
    data_list = []

    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        if os.path.isfile(file_path) and os.path.splitext(file_name.lower())[1] in valid_extensions:
            print(f"\nProcessing: {file_name}")
            extracted_text = extract_text_from_image(file_path)
            
            # Check if the first line matches a valid string
            first_line = extracted_text.splitlines()[0].strip() if extracted_text else ""
            if first_line in VALID_STRINGS:
                field_values = extract_field_values(extracted_text)
                field_values["File Name"] = file_name  # Add file name for reference
                data_list.append(field_values)
            else:
                print(f"Skipping {file_name}: First line does not match valid strings.")
        else:
            print(f"Skipping non-image file: {file_name}")

    # Print extracted data
    for data in data_list:
        print(data)

# Path to the folder containing images
folder_path = "C:\\Users\\welcome\\Documents\\Carrum\\"  # Update with the folder path containing images

# Process the folder and print data
process_folder(folder_path)
# Out:
# Skipping non-image file: Boooook.xlsx
# Skipping non-image file: Downloaded_Files
# Skipping non-image file: extracted_data_carrum.xlsx
# Skipping non-image file: MA3JMTB1SRFB19421 Invoice.pdf
# Skipping non-image file: MA3JMTB1SRFB19421 Policy.pdf
# Skipping non-image file: MA3JMTB1SRFB21380 Invoice.pdf
# Skipping non-image file: MA3JMTB1SRFB21380 Policy.pdf
# Skipping non-image file: MA3JMTB1SRFB21380 RC.png
# Skipping non-image file: MA3JMTB1SRFB21391 Invoice.pdf
# Skipping non-image file: MA3JMTB1SRFB21391 Policy.pdf
# Skipping non-image file: MA3JMTB1SRFB21391 RC.png
# Skipping non-image file: MA3JMTB1SRFB21432 Invoice.pdf
# Skipping non-image file: MA3JMTB1SRFB21432 Policy.pdf
# Skipping non-image file: MA3JMTB1SRFB21765 Invoice.pdf
# Skipping non-image file: MA3JMTB1SRFB21765 Policy.pdf
# Skipping non-image file: MA3JMTB1SRFB21765 RC.png
# Skipping non-image file: MA3JMTB1SRFB21810 Invoice.pdf
# Skipping non-image file: MA3JMTB1SRFB21810 Policy.pdf
# Skipping non-image file: MA3JMTB1SRFB21810 RC.png
# Skipping non-image file: MA3JMTB1SRFB21918 Invoice.pdf
# Skipping non-image file: MA3JMTB1SRFB21918 Policy.pdf
# Skipping non-image file: MA3JMTB1SRFB21918 RC.png
# Skipping non-image file: MA3JMTB1SRFB22113 Invoice.pdf
# Skipping non-image file: MA3JMTB1SRFB22113 Policy.pdf
# Skipping non-image file: MA3JMTB1SRFB22113 RC.png
# Skipping non-image file: MA3JMTB1SRFB22569 Invoice.pdf
# Skipping non-image file: MA3JMTB1SRFB22569 Policy.pdf
# Skipping non-image file: MA3JMTB1SRFB23008 Invoice.pdf
# Skipping non-image file: MA3JMTB1SRFB23008 Policy.pdf
# Skipping non-image file: MA3JMTB1SRFB23008 RC.png
# Skipping non-image file: MA3JMTB1SRGB30324 Invoice.pdf
# Skipping non-image file: MA3JMTB1SRGB30324 Policy.pdf
# Skipping non-image file: MA3JMTB1SRGB31597 Invoice.pdf
# Skipping non-image file: MA3JMTB1SRGB31597 Policy.pdf
# Skipping non-image file: MA3JMTB1SRGB33556 Invoice.pdf
# Skipping non-image file: MA3JMTB1SRGB33556 Policy.pdf
# Skipping non-image file: MA3JMTB1SRGB36609 Invoice.pdf
# Skipping non-image file: MA3JMTB1SRGB36609 Policy.pdf
# Skipping non-image file: MA3JMTB1SRGB36763 Invoice.pdf
# Skipping non-image file: MA3JMTB1SRGB36763 Policy.pdf
# Skipping non-image file: MA3JMTB1SRGB39281 Invoice.pdf
# Skipping non-image file: MA3JMTB1SRGB39281 Policy.pdf
# Skipping non-image file: MA3JMTB1SRGB39495 Invoice.pdf
# Skipping non-image file: MA3JMTB1SRGB39495 Policy.pdf
# Skipping non-image file: MA3JMTB1SRGB39753 Invoice.pdf
# Skipping non-image file: MA3JMTB1SRGB39753 Policy.pdf
# Skipping non-image file: MA3JMTB1SRGB39918 Invoice.pdf
# Skipping non-image file: MA3JMTB1SRGB39918 Policy.pdf
# Skipping non-image file: MA3JMTB1SRGB40274 Invoice.pdf
# Skipping non-image file: MA3JMTB1SRGB40274 Policy.pdf
# Skipping non-image file: MA3JMTB1SRGB40585 Invoice.pdf
# Skipping non-image file: MA3JMTB1SRGB40585 Policy.pdf
# Skipping non-image file: Screenshot and pdf in screenshot
#
# Processing: WhatsApp Image 2024-11-29 at 14.58.16_849056a5.jpg
# Skipping WhatsApp Image 2024-11-29 at 14.58.16_849056a5.jpg: First line does not match valid strings.
#
# Processing: WhatsApp Image 2024-11-29 at 14.58.52_a0282b93.jpg
# Skipping WhatsApp Image 2024-11-29 at 14.58.52_a0282b93.jpg: First line does not match valid strings.
#
# Processing: WhatsApp Image 2024-11-29 at 15.00.06_4ec87ba9.jpg
# Skipping WhatsApp Image 2024-11-29 at 15.00.06_4ec87ba9.jpg: First line does not match valid strings.
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.00_69bcefd5.jpg
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.06_9908b443.jpg
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.20_243f958d.jpg
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.21_9972adf7.jpg
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.21_d78d8a1a.jpg
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.22_20071314.jpg
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.23_15460e48.jpg
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.33_8a6ecdd3.jpg
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.35_58c81630.jpg
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.38_f6abbb70.jpg
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.42_2a97fe9a.jpg
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.43_3c073698.jpg
#
# Processing: WhatsApp Image 2024-11-30 at 12.47.50_a0510d9d.jpg
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.10_f29b3bd8.jpg
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.12_d80e226c.jpg
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.12_ea00f9cf.jpg
# Skipping WhatsApp Image 2024-11-30 at 12.49.12_ea00f9cf.jpg: First line does not match valid strings.
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.15_c606bbf6.jpg
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.16_2ba9c88f.jpg
# Skipping WhatsApp Image 2024-11-30 at 12.49.16_2ba9c88f.jpg: First line does not match valid strings.
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.16_da0bd9f7.jpg
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.17_a67969bd.jpg
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.18_b03423b4.jpg
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.19_0b2f0c91.jpg
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.19_c8f14133.jpg
#
# Processing: WhatsApp Image 2024-11-30 at 12.49.20_2419b764.jpg
# Skipping WhatsApp Image 2024-11-30 at 12.49.20_2419b764.jpg: First line does not match valid strings.
#
# Processing: WhatsApp Image 2024-11-30 at 13.10.58_7068a1cc.jpg
# Skipping WhatsApp Image 2024-11-30 at 13.10.58_7068a1cc.jpg: First line does not match valid strings.
#
# Processing: WhatsApp Image 2024-11-30 at 13.12.17_415afcd2.jpg
# Skipping WhatsApp Image 2024-11-30 at 13.12.17_415afcd2.jpg: First line does not match valid strings.
# Skipping non-image file: ~$extracted_data_carrum.xlsx
# {'Chassis Number': 'MA3JMTBISRKB85639', 'Registration Number': 'TGO7T8367', 'Mfg. Year': '10/10/2024', 'Registration Date': 'Not Found', 'File Name': 'WhatsApp Image 2024-11-30 at 12.47.00_69bcefd5.jpg'}
# {'Chassis Number': 'MA3JMTBISRKB85589', 'Registration Number': 'TGO7T8366', 'Mfg. Year': '10/10/2024', 'Registration Date': 'Not Found', 'File Name': 'WhatsApp Image 2024-11-30 at 12.47.06_9908b443.jpg'}
# {'Chassis Number': 'Engine', 'Registration Number': 'TG07T8373', 'Mfg. Year': '09/09/2024', 'Registration Date': '09/09/2024', 'File Name': 'WhatsApp Image 2024-11-30 at 12.47.20_243f958d.jpg'}
# {'Chassis Number': 'MA3JMTB1SRKB85798', 'Registration Number': 'TG07T8377', 'Mfg. Year': '10/10/2024', 'Registration Date': 'Not Found', 'File Name': 'WhatsApp Image 2024-11-30 at 12.47.21_9972adf7.jpg'}
# {'Chassis Number': 'Engine', 'Registration Number': 'TGO7T8376', 'Mfg. Year': '10/10/2024', 'Registration Date': '10/10/2024', 'File Name': 'WhatsApp Image 2024-11-30 at 12.47.21_d78d8a1a.jpg'}
# {'Chassis Number': 'MA3JMTB1SRKB85921', 'Registration Number': 'TGO7T8375', 'Mfg. Year': '10/10/2024', 'Registration Date': 'Not Found', 'File Name': 'WhatsApp Image 2024-11-30 at 12.47.22_20071314.jpg'}
# {'Chassis Number': 'MA3JMTBISRKB85899', 'Registration Number': 'TGO7T8374', 'Mfg. Year': '10/10/2024', 'Registration Date': 'Not Found', 'File Name': 'WhatsApp Image 2024-11-30 at 12.47.23_15460e48.jpg'}
# {'Chassis Number': 'MA3JMTB1SRJB73518', 'Registration Number': 'TGO7T8378', 'Mfg. Year': '09/09/2024', 'Registration Date': 'Not Found', 'File Name': 'WhatsApp Image 2024-11-30 at 12.47.33_8a6ecdd3.jpg'}
# {'Chassis Number': 'Engine', 'Registration Number': 'TGO7T8380', 'Mfg. Year': '09/09/2024', 'Registration Date': '09/09/2024', 'File Name': 'WhatsApp Image 2024-11-30 at 12.47.35_58c81630.jpg'}
# {'Chassis Number': 'MA3JMTBISRKB85840', 'Registration Number': 'TGO7T8381', 'Mfg. Year': '10/10/2024', 'Registration Date': 'Not Found', 'File Name': 'WhatsApp Image 2024-11-30 at 12.47.38_f6abbb70.jpg'}
# {'Chassis Number': 'MA3JMTBISRKB85620', 'Registration Number': 'TGO7T8382', 'Mfg. Year': '10/10/2024', 'Registration Date': 'Not Found', 'File Name': 'WhatsApp Image 2024-11-30 at 12.47.42_2a97fe9a.jpg'}
# {'Chassis Number': 'MA3JMTB1SRJB71942', 'Registration Number': 'TGO7T8386', 'Mfg. Year': '09/09/2024', 'Registration Date': 'Not Found', 'File Name': 'WhatsApp Image 2024-11-30 at 12.47.43_3c073698.jpg'}
# {'Chassis Number': 'Engine', 'Registration Number': 'TGO7T8385', 'Mfg. Year': '09/09/2024', 'Registration Date': '09/09/2024', 'File Name': 'WhatsApp Image 2024-11-30 at 12.47.50_a0510d9d.jpg'}
# {'Chassis Number': 'MA3JMTB1SRJB73690', 'Registration Number': 'TGO7T8383', 'Mfg. Year': '09/09/2024', 'Registration Date': 'Not Found', 'File Name': 'WhatsApp Image 2024-11-30 at 12.49.10_f29b3bd8.jpg'}
# {'Chassis Number': 'MA3JMTB1SRJB72127', 'Registration Number': 'TGO7T8384', 'Mfg. Year': '09/09/2024', 'Registration Date': 'Not Found', 'File Name': 'WhatsApp Image 2024-11-30 at 12.49.12_d80e226c.jpg'}
# {'Chassis Number': 'MA3JMTBISRKB85550', 'Registration Number': 'TGO7T8363', 'Mfg. Year': '10/10/2024', 'Registration Date': 'Not Found', 'File Name': 'WhatsApp Image 2024-11-30 at 12.49.15_c606bbf6.jpg'}
# {'Chassis Number': 'MA3JMTBISRKB85658', 'Registration Number': 'TGO7T8365', 'Mfg. Year': '10/10/2024', 'Registration Date': 'Not Found', 'File Name': 'WhatsApp Image 2024-11-30 at 12.49.16_da0bd9f7.jpg'}
# {'Chassis Number': 'Engine', 'Registration Number': 'TGO7T8368', 'Mfg. Year': '09/09/2024', 'Registration Date': '09/09/2024', 'File Name': 'WhatsApp Image 2024-11-30 at 12.49.17_a67969bd.jpg'}
# {'Chassis Number': 'MA3JMTB1SRKB85887', 'Registration Number': 'TGO7T8370', 'Mfg. Year': '10/10/2024', 'Registration Date': 'Not Found', 'File Name': 'WhatsApp Image 2024-11-30 at 12.49.18_b03423b4.jpg'}
# {'Chassis Number': 'Engine', 'Registration Number': 'TG07T8372', 'Mfg. Year': '09/09/2024', 'Registration Date': '09/09/2024', 'File Name': 'WhatsApp Image 2024-11-30 at 12.49.19_0b2f0c91.jpg'}
# {'Chassis Number': 'MA3JMTB1SRKB85779', 'Registration Number': 'TG07T8371', 'Mfg. Year': '10/10/2024', 'Registration Date': 'Not Found', 'File Name': 'WhatsApp Image 2024-11-30 at 12.49.19_c8f14133.jpg'}

# %% [markdown]
# # Complete code (with Invoice and Policy) only print

# %%
import re
import pdfplumber

# Code 1: Process invoices with specific format
def process_invoice_pdf(pdf_path):
    data = {
        "Chassis Number": "Not found",
        "Color": "Not found",
        "Place of Supply": "Not found",
        "From": "Not found",
        "Invoice No.": "Not found",
        "Invoice Date": "Not found",
        "Owner": "Not found",
        "Ex-showroom Price": "₹6,41,500",  # Fixed value
        "Total Invoice Amount": "Not found",
        "Discount": "Not found",
        "Variant Description": "Not found",
        "Engine Number": "Not found",
    }

    
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            lines = page.extract_text().split("\n")  # Extract and split text into lines

            for line in lines:
                # Debugging: Uncomment to print each line
                
                #print(f"Line: {line}")

                # 1. Chassis Number
                if "Vehicle ID" in line:
                    match = re.search(r"Vehicle ID\s*:\s*([A-Z0-9]+)", line)
                    if match:
                        data["Chassis Number"] = match.group(1)

                # 2. Engine Number
                if data["Chassis Number"] != "Not found" and "Superior" in line:
                    chassis_match = re.search(data["Chassis Number"], line)
                    if chassis_match:
                        engine_match = re.search(rf"{data['Chassis Number']}\s+([A-Z0-9\s]+)\s+Superior", line)
                        if engine_match:
                            data["Engine Number"] = engine_match.group(1).strip()

                # 3. Color
                if "Superior" in line:
                    match = re.search(r"(Superior\s\w+-\d+U)", line, re.IGNORECASE)
                    if match:
                        data["Color"] = match.group(1)

                # 4. Place of Supply
                if "Place of Supply" in line:
                    match = re.search(r"Place of Supply\s*:\s*([\w\s]+\(\d+\))", line)
                    if match:
                        data["Place of Supply"] = match.group(1)

                # 5. From (Dealer Information)
                if "For" in line and "PVT LTD" in line:
                    match = re.search(r"For\s+([\w\s\.\-]+PVT LTD)", line, re.IGNORECASE)
                    if match:
                        data["From"] = match.group(1).strip()

                # 6. Invoice No.
                if "Invoice No." in line:
                    # Look for "Invoice No." and capture it
                    match = re.search(r"Invoice No\.\s*[:\-]?\s*([\w\/\-]+)", line)
                    if match:
                        data["Invoice No."] = match.group(1)

                # 7. Invoice Date
                if "Invoice Date" in line:
                    match = re.search(r"Invoice Date\s*:\s*([\d/]+\s+\d{2}:\d{2}\s+[APM]{2})", line)
                    if match:
                        data["Invoice Date"] = match.group(1)

                # 8. Owner
                if "Sold To" in line:
                    # This will match the "Sold To" line and capture everything after "Sold To :"
                    match = re.search(r"Sold To\s*:\s*(.+)", line, re.IGNORECASE)
                    if match:
                        data["Owner"] = match.group(1).strip()
    

                # 9. Total Invoice Amount
                if "Total Invoice Amount" in line:
                    match = re.search(r"Total Invoice Amount\s*:\s*([\d,]+\.\d{2})", line)
                    if match:
                        data["Total Invoice Amount"] = match.group(1)

                # 10. Variant Description
                if "PRICE OF ONE" in line:
                    match = re.search(r"PRICE OF ONE\s+([\w\s]+)-", line)
                    if match:
                        data["Variant Description"] = match.group(1).strip()

    # Calculate Discount
    if data["Total Invoice Amount"] != "Not found":
        ex_showroom_price = 641500.00
        total_invoice = float(data["Total Invoice Amount"].replace(",", ""))
        data["Discount"] = f"₹{ex_showroom_price - total_invoice:.2f}"

    return data

# Code 2: Process insurance policy PDFs with specific company
def process_insurance_pdf_shreyash(pdf_path):
    extracted_details = {
        "Insurance Company": None,
        "Policy Number": None,
        "INSURED’S DECLARED VALUE (IDV)": None,
        "Insurance Premium": None,
        "Start Date": None,
        "End Date": None,
        "Chassis Number": None
    }


    with pdfplumber.open(pdf_path) as pdf:
        for page_number, page in enumerate(pdf.pages):
            lines = page.extract_text().split("\n")  # Extract and split text into lines
            #print(f"--- Page {page_number + 1} ---")  # Debugging: Print page number
            
            for i, line in enumerate(lines):
                #print(f"Line {i}: {line.strip()}")  # Debugging: Print each line

                # 1. Insurance Company
                if "T h i s i s n o t a p a r t o f t h e p o l i c y d o c u m e n t" in line:
                    if i + 1 < len(lines):  # Check if next line exists
                        extracted_details["Insurance Company"] = lines[i + 1].strip()
                       # print(f"Extracted Insurance Company: {extracted_details['Insurance Company']}")  # Debugging

                # 2. Policy Number
                if "Policy No" in line:
                    match = re.search(r"Policy No\s+(\w+)", line)
                    if match:
                        extracted_details["Policy Number"] = match.group(1)
                      #  print(f"Extracted Policy Number: {extracted_details['Policy Number']}")  # Debugging

                # 3. INSURED’S DECLARED VALUE (IDV)
                if "Total IDV ₹" in line:
                    match = re.search(r"Total IDV ₹\s*([\d,]+)", line)
                    if match:
                        extracted_details["INSURED’S DECLARED VALUE (IDV)"] = match.group(1).replace(",", "")
                      #  print(f"Extracted IDV: {extracted_details['INSURED’S DECLARED VALUE (IDV)']}")  # Debugging

                # 4. Insurance Premium
                if "Gross Premium Paid ₹" in line:
                    match = re.search(r"Gross Premium Paid ₹\s*([\d,]+)", line)
                    if match:
                        extracted_details["Insurance Premium"] = match.group(1).replace(",", "")
                      #  print(f"Extracted Insurance Premium: {extracted_details['Insurance Premium']}")  # Debugging

                # 5. Start Date
                if "Period of Insurance" in line:
                    match = re.search(r"Period of Insurance\s+(\d{2}-[A-Z]{3}-\d{4})", line)
                    if match:
                        extracted_details["Start Date"] = match.group(1)
                      #  print(f"Extracted Start Date: {extracted_details['Start Date']}")  # Debugging

                # 6. End Date
                if "to" in line and "Period of Insurance" in line:
                    match = re.search(r"to\s+(\d{2}-[A-Z]{3}-\d{4})", line)
                    if match:
                        extracted_details["End Date"] = match.group(1)
                      #  print(f"Extracted End Date: {extracted_details['End Date']}")  # Debugging

                # 7. Chassis Number
                if "Vehicle Identification No." in line:
                    match = re.search(r"Vehicle Identification No\.\s+([A-Z0-9]+)", line)
                    if match:
                        extracted_details["Chassis Number"] = match.group(1)
                       # print(f"Extracted Chassis Number: {extracted_details['Chassis Number']}")  # Debugging

    return extracted_details




# Code 3: Process insurance PDFs with SBI-specific format
def process_insurance_pdf_sbi(pdf_path):
    extracted_details= {
        "Insurance Company": None,
        "Policy Number": None,
        "INSURED’S DECLARED VALUE (IDV)": None,
        "Insurance Premium": None,
        "Start Date": None,
        "End Date": None,
        "Chassis Number": None
    }


    with pdfplumber.open(pdf_path) as pdf:
        for page_number, page in enumerate(pdf.pages):
            lines = page.extract_text().split("\n")  # Extract and split text into lines
            #print(f"--- Page {page_number + 1} ---")  # Debugging: Print page number
            
            for i, line in enumerate(lines):
                #print(f"Line {i}: {line.strip()}")  # Debugging: Print each line

                # 1. Insurance Company
                if "The Postal Address of your SBI General Branch that will service you in future is:" in line:
                    if i + 1 < len(lines):  # Check if next line exists
                        extracted_details["Insurance Company"] = lines[i + 1].strip()
                        #print(f"Extracted Insurance Company: {extracted_details['Insurance Company']}")  # Debugging

                # 2. Policy Number
                if "Your Policy No. :" in line:
                    match = re.search(r"Your Policy No\. :(\d+)", line)
                    if match:
                        extracted_details["Policy Number"] = match.group(1)
                        #print(f"Extracted Policy Number: {extracted_details['Policy Number']}")  # Debugging

                # 3. INSURED’S DECLARED VALUE (IDV)
                if "INSURED’S DECLARED VALUE (IDV)" in line:
                    if i + 4 < len(lines):  # Check if 4th line after exists
                        idv_line = lines[i + 4].strip()
                        match = re.search(r"(\d{1,3}(,\d{3})*(\.\d{2})?)", idv_line)
                        if match:
                            extracted_details["INSURED’S DECLARED VALUE (IDV)"] = match.group(1).split(".")[0]
                        #    print(f"Extracted IDV: {extracted_details['INSURED’S DECLARED VALUE (IDV)']}")  # Debugging

                # 4. Insurance Premium
                if "Total Premium Collected" in line:
                    match = re.search(r"Total Premium Collected\s+([\d,]+\.\d{2})", line)
                    if match:
                        extracted_details["Insurance Premium"] = match.group(1)
                      #  print(f"Extracted Insurance Premium: {extracted_details['Insurance Premium']}")  # Debugging

                # 5. Start Date
                if "Period of Insurance : From :" in line:
                    match = re.search(r"From\s*:(\d{2}/\d{2}/\d{4})", line)
                    if match:
                        extracted_details["Start Date"] = match.group(1)
                      #  print(f"Extracted Start Date: {extracted_details['Start Date']}")  # Debugging

                # 6. End Date
                if "Period of Insurance : From :" in line:
                    match = re.search(r"Midnight of:\s*(\d{2}/\d{2}/\d{4})", line)
                    if match:
                        extracted_details["End Date"] = match.group(1)
                      #  print(f"Extracted End Date: {extracted_details['End Date']}")  # Debugging
                # 7.Chassis Number 
                if "Chassis Number" in line:
                    match = re.search(r"Chassis Number\s+([A-Z0-9]+)", line)
                    if match:
                        extracted_details["Chassis Number"] = match.group(1)
                       # print(f"Extracted Chassis Number: {extracted_details['Chassis Number']}")  # Debugging


    return extracted_details

# Main function to process the PDF
import os
import pdfplumber

# Main function to process the PDF
def process_pdf_based_on_type(pdf_path):
    with pdfplumber.open(pdf_path) as pdf:
        first_page_text = pdf.pages[0].extract_text()

    if "TAX / VEHICLE & CHARGES INVOICE" in first_page_text:
        print("Processing Invoice PDF...")
        return process_invoice_pdf(pdf_path)
    elif "SHREYASH AUTOMOTIVES PRIVATE LIMIT" in first_page_text:
        print("Processing Insurance PDF (Shreyash)...")
        return process_insurance_pdf_shreyash(pdf_path)
    elif "The Postal Address of your SBI General Branch" in first_page_text:
        print("Processing Insurance PDF (SBI)...")
        return process_insurance_pdf_sbi(pdf_path)
    else:
        print("Unknown PDF format.")
        return None

# Function to process all PDFs in a folder
def process_pdfs_in_folder(folder_path):
    # List all files in the folder
    files = os.listdir(folder_path)

    # Filter only PDF files
    pdf_files = [f for f in files if f.lower().endswith('.pdf')]

    # Process each PDF
    for pdf_file in pdf_files:
        pdf_path = os.path.join(folder_path, pdf_file)
        try:
            extracted_data = process_pdf_based_on_type(pdf_path)
            if extracted_data:
                print("\nExtracted Data:")
                for key, value in extracted_data.items():
                    print(f"{key}: {value}")
                print("-" * 50)
            else:
                print(f"No data extracted from {pdf_path}.")
        except Exception as e:
            print(f"Error processing {pdf_path}: {e}")

# Main function to specify folder location and process PDFs
if __name__ == "__main__":
    folder_path = "C:\\Users\\welcome\\Documents\\Carrum\\"  # Replace with your folder path
    process_pdfs_in_folder(folder_path)
# Out:
# Unknown PDF format.
# No data extracted from C:\Users\welcome\Documents\Carrum\MA3JMTB1SRFB18866 Invoice & Policy.pdf.
# Unknown PDF format.
# No data extracted from C:\Users\welcome\Documents\Carrum\MA3JMTB1SRFB18876 Invoice & Policy.pdf.
# Unknown PDF format.
# No data extracted from C:\Users\welcome\Documents\Carrum\MA3JMTB1SRFB18918 Invoice & Policy.pdf.
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB19421
# Color: Superior White-26U
# Place of Supply: TELANGANA(36)
# From: VARUN MOTORS PVT LTD
# Invoice No.: 12/VSL/24002577
# Invoice Date: 28/08/2024 04:34 PM
# Owner: M/S. CARRUM MOBILITY SOLUTIONS PVT LTD
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,58,500.00
# Discount: ₹83000.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C597750
# --------------------------------------------------
# Processing Insurance PDF (SBI)...
#
# Extracted Data:
# Insurance Company: SBI General Insurance Company Limited
# Policy Number: 0000000040526381
# INSURED’S DECLARED VALUE (IDV): 530,575
# Insurance Premium: 22,194.00
# Start Date: 28/08/2024
# End Date: 27/08/2025
# Chassis Number: MA3JMTB1SRFB19421
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB21432
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 2/VSL/24000612
# Invoice Date: 29/06/2024 09:20 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,48,001.00
# Discount: ₹93499.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C600263
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Insurance Company: Go Digit General Insurance Ltd.
# Policy Number: D154233800
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 22009
# Start Date: 30-JUN-2024
# End Date: 29-JUN-2025
# Chassis Number: MA3JMTB1SRFB21432
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRFB22569
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 2/VSL/24000633
# Invoice Date: 29/06/2024 11:12 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,48,001.00
# Discount: ₹93499.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C602455
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Insurance Company: Go Digit General Insurance Ltd.
# Policy Number: D154235846
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 22009
# Start Date: 30-JUN-2024
# End Date: 29-JUN-2025
# Chassis Number: MA3JMTB1SRFB22569
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB30324
# Color: Superior White-26U
# Place of Supply: TELANGANA(36)
# From: VARUN MOTORS PVT LTD
# Invoice No.: 12/VSL/24002553
# Invoice Date: 28/08/2024 02:55 PM
# Owner: M/S. CARRUM MOBILITY SOLUTIONS PVT LTD
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,58,500.00
# Discount: ₹83000.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C613908
# --------------------------------------------------
# Processing Insurance PDF (SBI)...
#
# Extracted Data:
# Insurance Company: SBI General Insurance Company Limited
# Policy Number: 0000000040527221
# INSURED’S DECLARED VALUE (IDV): 530,575
# Insurance Premium: 22,194.00
# Start Date: 28/08/2024
# End Date: 27/08/2025
# Chassis Number: MA3JMTB1SRGB30324
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB31597
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 2/VSL/24001104
# Invoice Date: 31/07/2024 08:34 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,48,002.00
# Discount: ₹93498.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C616602
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Insurance Company: Go Digit General Insurance Ltd.
# Policy Number: D158999638
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 20950
# Start Date: 31-JUL-2024
# End Date: 30-JUL-2025
# Chassis Number: MA3JMTB1SRGB31597
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB33556
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 2/VSL/24001106
# Invoice Date: 31/07/2024 08:38 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,48,002.00
# Discount: ₹93498.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C619581
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Insurance Company: Go Digit General Insurance Ltd.
# Policy Number: D158999607
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 20950
# Start Date: 31-JUL-2024
# End Date: 30-JUL-2025
# Chassis Number: MA3JMTB1SRGB33556
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB36609
# Color: Superior White-26U
# Place of Supply: TELANGANA(36)
# From: VARUN MOTORS PVT LTD
# Invoice No.: 12/VSL/24002534
# Invoice Date: 27/08/2024 10:47 PM
# Owner: M/S. CARRUM MOBILITY SOLUTIONS PVT LTD
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,58,500.00
# Discount: ₹83000.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C624099
# --------------------------------------------------
# Processing Insurance PDF (SBI)...
#
# Extracted Data:
# Insurance Company: SBI General Insurance Company Limited
# Policy Number: 0000000040529253
# INSURED’S DECLARED VALUE (IDV): 530,575
# Insurance Premium: 22,194.00
# Start Date: 28/08/2024
# End Date: 27/08/2025
# Chassis Number: MA3JMTB1SRGB36609
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB36763
# Color: Superior White-26U
# Place of Supply: TELANGANA(36)
# From: VARUN MOTORS PVT LTD
# Invoice No.: 12/VSL/24002529
# Invoice Date: 27/08/2024 09:31 PM
# Owner: M/S. CARRUM MOBILITY SOLUTIONS PVT LTD
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,58,500.00
# Discount: ₹83000.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C624527
# --------------------------------------------------
# Processing Insurance PDF (SBI)...
#
# Extracted Data:
# Insurance Company: SBI General Insurance Company Limited
# Policy Number: 0000000040528384
# INSURED’S DECLARED VALUE (IDV): 530,575
# Insurance Premium: 22,194.00
# Start Date: 28/08/2024
# End Date: 27/08/2025
# Chassis Number: MA3JMTB1SRGB36763
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB39281
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 1/VSL/24001340
# Invoice Date: 10/08/2024 03:19 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,48,000.00
# Discount: ₹93500.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C626687
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Insurance Company: Go Digit General Insurance Ltd.
# Policy Number: D160097683
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 22007
# Start Date: 10-AUG-2024
# End Date: 09-AUG-2025
# Chassis Number: MA3JMTB1SRGB39281
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB39753
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 1/VSL/24001338
# Invoice Date: 10/08/2024 03:14 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,48,000.00
# Discount: ₹93500.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C627530
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Insurance Company: Go Digit General Insurance Ltd.
# Policy Number: D160096884
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 22009
# Start Date: 10-AUG-2024
# End Date: 09-AUG-2025
# Chassis Number: MA3JMTB1SRGB39753
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB39918
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 1/VSL/24001339
# Invoice Date: 10/08/2024 03:16 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,48,000.00
# Discount: ₹93500.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C627391
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Insurance Company: Go Digit General Insurance Ltd.
# Policy Number: D160097343
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 22009
# Start Date: 10-AUG-2024
# End Date: 09-AUG-2025
# Chassis Number: MA3JMTB1SRGB39918
# --------------------------------------------------
# Processing Invoice PDF...
#
# Extracted Data:
# Chassis Number: MA3JMTB1SRGB40274
# Color: Superior White-26U
# Place of Supply: HARYANA(06)
# From: SHREYASH AUTOMOTIVES PVT LTD
# Invoice No.: 2/VSL/24001160
# Invoice Date: 13/08/2024 01:03 PM
# Owner: CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,48,000.00
# Discount: ₹93500.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C628938
# --------------------------------------------------
# Processing Insurance PDF (Shreyash)...
#
# Extracted Data:
# Insurance Company: Go Digit General Insurance Ltd.
# Policy Number: D160680924
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 20950
# Start Date: 14-AUG-2024
# End Date: 13-AUG-2025
# Chassis Number: MA3JMTB1SRGB40274
# --------------------------------------------------

# %% [markdown]
# # Go Digit General Insurance Ltd.

# %%
import re
import pdfplumber

def extract_pdf_details_for_digit(pdf_path):
    extracted_details = {
        "Insurance Company": "Go Digit General Insurance Ltd.",
        "Policy Number": None,
        "INSURED’S DECLARED VALUE (IDV)": None,
        "Insurance Premium": None,
        "Start Date": None,
        "End Date": None,
        "Chassis Number": None
    }

    # Open the PDF
    with pdfplumber.open(pdf_path) as pdf:
        for page_number, page in enumerate(pdf.pages):
            lines = page.extract_text().split("\n")  # Extract and split text into lines
            #print(f"--- Page {page_number + 1} ---")  # Debugging: Print page number
            
            for i, line in enumerate(lines):
                #print(f"Line {i}: {line.strip()}")  # Debugging: Print each line

                # # 1. Insurance Company
                # if "For" in line and "Ltd" in line:
                #     match = re.search(r"For\s+([\w\s\.\-])", line, re.IGNORECASE)
                #     if match:
                #          extracted_details["From"] = match.group(1).strip()

                # 2. Policy Number
                if "Policy No" in line:
                    match = re.search(r"Policy No\s+(\w+)", line)
                    if match:
                        extracted_details["Policy Number"] = match.group(1)
                      #  print(f"Extracted Policy Number: {extracted_details['Policy Number']}")  # Debugging

                # 3. INSURED’S DECLARED VALUE (IDV)
                if "Total IDV ₹" in line:
                    match = re.search(r"Total IDV ₹\s*([\d,]+)", line)
                    if match:
                        extracted_details["INSURED’S DECLARED VALUE (IDV)"] = match.group(1).replace(",", "")
                      #  print(f"Extracted IDV: {extracted_details['INSURED’S DECLARED VALUE (IDV)']}")  # Debugging

                # 4. Insurance Premium
                if "Gross Premium Paid ₹" in line:
                    match = re.search(r"Gross Premium Paid ₹\s*([\d,]+)", line)
                    if match:
                        extracted_details["Insurance Premium"] = match.group(1).replace(",", "")
                      #  print(f"Extracted Insurance Premium: {extracted_details['Insurance Premium']}")  # Debugging

                # 5. Start Date
                if "Period of Insurance" in line:
                    match = re.search(r"Period of Insurance\s+(\d{2}-[A-Z]{3}-\d{4})", line)
                    if match:
                        extracted_details["Start Date"] = match.group(1)
                      #  print(f"Extracted Start Date: {extracted_details['Start Date']}")  # Debugging

                # 6. End Date
                if "to" in line and "Period of Insurance" in line:
                    match = re.search(r"to\s+(\d{2}-[A-Z]{3}-\d{4})", line)
                    if match:
                        extracted_details["End Date"] = match.group(1)
                      #  print(f"Extracted End Date: {extracted_details['End Date']}")  # Debugging

                # 7. Chassis Number
                if "Vehicle Identification No." in line:
                    match = re.search(r"Vehicle Identification No\.\s+([A-Z0-9]+)", line)
                    if match:
                        extracted_details["Chassis Number"] = match.group(1)
                        #print(f"Extracted Chassis Number: {extracted_details['Chassis Number']}")  # Debugging

    return extracted_details
 

# Path to PDF file
pdf_path = "C:\\Users\\welcome\\Documents\\Carrum\\MA3JMTB1SRGB33556 Policy.pdf"

# Extract details
details = extract_pdf_details_for_digit(pdf_path)
print("\nFinal Extracted Details:")

for key, value in details.items():
    print(f"{key}: {value}")
# Out:
# Final Extracted Details:
# Insurance Company: Go Digit General Insurance Ltd.
# Policy Number: D158999607
# INSURED’S DECLARED VALUE (IDV): 520600
# Insurance Premium: 20950
# Start Date: 31-JUL-2024
# End Date: 30-JUL-2025
# Chassis Number: MA3JMTB1SRGB33556

# %% [markdown]
# # SBI General Insurance Company Limited

# %%
import re
import pdfplumber

def extract_pdf_details_with_pdfplumber(pdf_path):
    extracted_details = {
        "Insurance Company": None,
        "Policy Number": None,
        "INSURED’S DECLARED VALUE (IDV)": None,
        "Insurance Premium": None,
        "Start Date": None,
        "End Date": None,
        "Chassis Number" : None
    }

    # Open the PDF
    with pdfplumber.open(pdf_path) as pdf:
        for page_number, page in enumerate(pdf.pages):
            lines = page.extract_text().split("\n")  # Extract and split text into lines
            #print(f"--- Page {page_number + 1} ---")  # Debugging: Print page number
            
            for i, line in enumerate(lines):
                #print(f"Line {i}: {line.strip()}")  # Debugging: Print each line

                # 1. Insurance Company
                if "The Postal Address of your SBI General Branch that will service you in future is:" in line:
                    if i + 1 < len(lines):  # Check if next line exists
                        extracted_details["Insurance Company"] = lines[i + 1].strip()
                        #print(f"Extracted Insurance Company: {extracted_details['Insurance Company']}")  # Debugging

                # 2. Policy Number
                if "Your Policy No. :" in line:
                    match = re.search(r"Your Policy No\. :(\d+)", line)
                    if match:
                        extracted_details["Policy Number"] = match.group(1)
                        #print(f"Extracted Policy Number: {extracted_details['Policy Number']}")  # Debugging

                # 3. INSURED’S DECLARED VALUE (IDV)
                if "INSURED’S DECLARED VALUE (IDV)" in line:
                    if i + 4 < len(lines):  # Check if 4th line after exists
                        idv_line = lines[i + 4].strip()
                        match = re.search(r"(\d{1,3}(,\d{3})*(\.\d{2})?)", idv_line)
                        if match:
                            extracted_details["INSURED’S DECLARED VALUE (IDV)"] = match.group(1).split(".")[0]
                        #    print(f"Extracted IDV: {extracted_details['INSURED’S DECLARED VALUE (IDV)']}")  # Debugging

                # 4. Insurance Premium
                if "Total Premium Collected" in line:
                    match = re.search(r"Total Premium Collected\s+([\d,]+\.\d{2})", line)
                    if match:
                        extracted_details["Insurance Premium"] = match.group(1)
                      #  print(f"Extracted Insurance Premium: {extracted_details['Insurance Premium']}")  # Debugging

                # 5. Start Date
                if "Period of Insurance : From :" in line:
                    match = re.search(r"From\s*:(\d{2}/\d{2}/\d{4})", line)
                    if match:
                        extracted_details["Start Date"] = match.group(1)
                      #  print(f"Extracted Start Date: {extracted_details['Start Date']}")  # Debugging

                # 6. End Date
                if "Period of Insurance : From :" in line:
                    match = re.search(r"Midnight of:\s*(\d{2}/\d{2}/\d{4})", line)
                    if match:
                        extracted_details["End Date"] = match.group(1)
                      #  print(f"Extracted End Date: {extracted_details['End Date']}")  # Debugging
                # 7.Chassis Number 
                if "Chassis Number" in line:
                    match = re.search(r"Chassis Number\s+([A-Z0-9]+)", line)
                    if match:
                        extracted_details["Chassis Number"] = match.group(1)
                       # print(f"Extracted Chassis Number: {extracted_details['Chassis Number']}")  # Debugging


    return extracted_details

# Path to PDF file
pdf_path = "C:\\Users\\welcome\\Documents\\Carrum\\MA3JMTB1SRGB30324 Policy.pdf"

# Extract details
details = extract_pdf_details_with_pdfplumber(pdf_path)
print("\nFinal Extracted Details:")
for key, value in details.items():
    print(f"{key}: {value}")
# Out:
# Final Extracted Details:
# Insurance Company: SBI General Insurance Company Limited
# Policy Number: 0000000040527221
# INSURED’S DECLARED VALUE (IDV): 530,575
# Insurance Premium: 22,194.00
# Start Date: 28/08/2024
# End Date: 27/08/2025
# Chassis Number: MA3JMTB1SRGB30324

# %% [markdown]
# # INVOICE

# %%
import re
import pdfplumber

def process_pdf_line_by_line(pdf_path):
    data = {
        "Chassis Number": "Not found",
        "Color": "Not found",
        "Place of Supply": "Not found",
        "From": "Not found",
        "Invoice No.": "Not found",
        "Invoice Date": "Not found",
        "Owner": "Not found",
        "Ex-showroom Price": "₹6,41,500",  # Fixed value
        "Total Invoice Amount": "Not found",
        "Discount": "Not found",
        "Variant Description": "Not found",
        "Engine Number": "Not found",
    }

    # Open the PDF
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            lines = page.extract_text().split("\n")  # Extract and split text into lines

            for line in lines:
                # Debugging: Uncomment to print each line
                
                #print(f"Line: {line}")

                # 1. Chassis Number
                if "Vehicle ID" in line:
                    match = re.search(r"Vehicle ID\s*:\s*([A-Z0-9]+)", line)
                    if match:
                        data["Chassis Number"] = match.group(1)

                # 2. Engine Number
                if data["Chassis Number"] != "Not found" and "Superior" in line:
                    chassis_match = re.search(data["Chassis Number"], line)
                    if chassis_match:
                        engine_match = re.search(rf"{data['Chassis Number']}\s+([A-Z0-9\s]+)\s+Superior", line)
                        if engine_match:
                            data["Engine Number"] = engine_match.group(1).strip()

                # 3. Color
                if "Superior" in line:
                    match = re.search(r"(Superior\s\w+-\d+U)", line, re.IGNORECASE)
                    if match:
                        data["Color"] = match.group(1)

                # 4. Place of Supply
                if "Place of Supply" in line:
                    match = re.search(r"Place of Supply\s*:\s*([\w\s\(\)\d]+)", line)
                    if match:
                        data["Place of Supply"] = match.group(1)

                # 5. From (Dealer Information)
                if "For" in line and "PVT LTD" in line:
                    match = re.search(r"For\s+([\w\s\.\-]+PVT LTD)", line, re.IGNORECASE)
                    if match:
                        data["From"] = match.group(1).strip()

                # 6. Invoice No.
                if "Invoice No." in line:
                    # Look for "Invoice No." and capture it
                    match = re.search(r"Invoice No\.\s*[:\-]?\s*([\w\/\-]+)", line)
                    if match:
                        data["Invoice No."] = match.group(1)

                # 7. Invoice Date
                if "Invoice Date" in line:
                    match = re.search(r"Invoice Date\s*:\s*([\d/]+\s+\d{2}:\d{2}\s+[APM]{2})", line)
                    if match:
                        data["Invoice Date"] = match.group(1)

                # 8. Owner
                if "Sold To" in line:
                    # This will match the "Sold To" line and capture everything after "Sold To :"
                    match = re.search(r"Sold To\s*:\s*(.+)", line, re.IGNORECASE)
                    if match:
                        data["Owner"] = match.group(1).strip()
    

                # 9. Total Invoice Amount
                if "Total Invoice Amount" in line:
                    match = re.search(r"Total Invoice Amount\s*:\s*([\d,]+\.\d{2})", line)
                    if match:
                        data["Total Invoice Amount"] = match.group(1)

                # 10. Variant Description
                if "PRICE OF ONE" in line:
                    match = re.search(r"PRICE OF ONE\s+([\w\s]+)-", line)
                    if match:
                        data["Variant Description"] = match.group(1).strip()

    # Calculate Discount
    if data["Total Invoice Amount"] != "Not found":
        ex_showroom_price = 641500.00
        total_invoice = float(data["Total Invoice Amount"].replace(",", ""))
        data["Discount"] = f"₹{ex_showroom_price - total_invoice:.2f}"

    return data


# Path to PDF file
pdf_path = "C:\\Users\\welcome\\Documents\\Carrum\\MA3JMTB1SRGB36609 Invoice.pdf"

# Extract and process the data
extracted_data = process_pdf_line_by_line(pdf_path)

# Print results
for key, value in extracted_data.items():
    print(f"{key}: {value}")
# Out:
# Chassis Number: MA3JMTB1SRGB36609
# Color: Superior White-26U
# Place of Supply: TELANGANA(36) Order No
# From: VARUN MOTORS PVT LTD
# Invoice No.: 12/VSL/24002534
# Invoice Date: 27/08/2024 10:47 PM
# Owner: M/S. CARRUM MOBILITY SOLUTIONS PVT LTD
# Ex-showroom Price: ₹6,41,500
# Total Invoice Amount: 5,58,500.00
# Discount: ₹83000.00
# Variant Description: MARUTI TOUR H3 CNG 1L 5MT
# Engine Number: K10CN C624099

# %%
"C:\\Users\\welcome\\Documents\\Carrum\\MA3JMTB1SRFB19421 Invoice.pdf"
# Out:
# 'C:\\Users\\welcome\\Documents\\Carrum\\MA3JMTB1SRFB19421 Invoice.pdf'

# %% [markdown]
# # for Print text Available in Pdf

# %%
import re
import pdfplumber

# Path to PDF file
pdf_path = "C:\\Users\\welcome\\Documents\\Carrum\\MA3JMTB1SRFB19421 Invoice.pdf"

# Open the PDF
with pdfplumber.open(pdf_path) as pdf:
    for page in pdf.pages:
        lines = page.extract_text().split("\n")  # Extract and split text into lines

        for line in lines:
            # Debugging: Uncomment to print each line
            print(f"Line: {line}")
# Out:
# Line: ORIGINAL FOR RECIPIENT/DUPLICATE FOR TRANSPORTER/TRIPLICATE FOR SUPPLIER
# Line: TAX / VEHICLE & CHARGES INVOICE
# Line: Sold To : M/S. CARRUM MOBILITY SOLUTIONS PVT LTD
# Line: Guardian of : REP BY: SADAMUDDIN CHOUHAN
# Line: Address : FNO: 504, ANURAG TOWERS, 100 FEET RD,
# Line: AYYAPPA SOCIETY,SIDDI VINAYAK NAGAR
# Line: MADHAPUR, HYD HYDERABAD
# Line: Pin:500081,(M):6304982820 TELANGANA (36)
# Line: Customer ID : 2457565262 PAN No :AALCC8489R
# Line: Financed By : STATE BANK OF INDIA, MID CORPORAT BRANCH,
# Line: GURUGRAM
# Line: Invoice No. : 12/VSL/24002577
# Line: Customer Aadhar No. :
# Line: Invoice Date : 28/08/2024 04:34 PM
# Line: Place of Supply : TELANGANA(36) Order No. : SOB24002691
# Line: Vehicle ID : MA3JMTB1SRFB19421
# Line: Order Date : 30/07/2024
# Line: Customer Mobile No. : 6304982820
# Line: Key No. : 2906
# Line: Booking Dealer :
# Line: Delivery Dealer : 4603
# Line: Customer GST No. : 36AALCC8489R1ZE
# Line: Dealer GST No. : 36AABCV2471Q1ZT
# Line: Dealer PAN No. : AABCV2471Q
# Line: IRN : 00cb4b64290d845b44c7424e5f29265dc80aa92880be11429fa909c166517275
# Line: Price Dr Amount Cr Amount
# Line: 1PRICE OF ONE MARUTI TOUR H3 CNG 1L 5MT- 4,97,286.96
# Line: WARCIT1
# Line: CHASSIS NO. ENGINE NO. COLOR HSN EMISSION NORM
# Line: MA3JMTB1SRFB19421 K10CN C597750 Superior White-26U 87032191 Bharat Stage 6
# Line: 2 Discount for Corp/Institutional/RSL Customer 0.00 23,256.00
# Line: 3 DISCOUNT 0.00 41,085.50
# Line: 4 MSSF Special Offer 0.00 0.00
# Line: 5 Additional Discount 2 0.00 0.00
# Line: 6 Additional Discount 1 0.00 0.00
# Line: 7 Exchange / Loyalty Bonus Discount 0.00 0.00
# Line: 8 Assessable Value 4,32,945.46
# Line: 9 CGST @ 14% 60,612.36
# Line: 10 SGST @ 14% 60,612.36
# Line: 11 Cess @ 1 % 4,329.45
# Line: Sub Total Amount (Assessable Value + Tax) : 5,58,499.63
# Line: Total Round Off Amount :: 0.37
# Line: Total Invoice Amount : 5,58,500.00
# Line: Invoice Amount in words : Rupees Five Lakh Fifty Eight Thousand Five Hundred Only
# Line: Loyalty Additional bonus point are awarded in customer loyalty account :
# Line: Loyalty Points Redemption :
# Line: Customer Name & Signatory For VARUN MOTORS PVT LTD
# Line: (M/S. CARRUM MOBILITY SOLUTIONS PVT LTD) (Authorized Signatory)
# Line: Created By : LAKAKULA SRI GOURI Created Date : 28-AUG-2024 16:34:09
# Line: Rel 2.5.30

# %% [markdown]
# # Extract data in all Images available in folder

# %%
import pytesseract
from PIL import Image
import re
import os

# Specify the path to the Tesseract executable
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def extract_text_from_image(image_path):
    """
    Extract text from an image using Tesseract OCR.
    
    Args:
        image_path (str): Path to the image file.
        
    Returns:
        str: Extracted text from the image.
    """
    try:
        # Open the image using PIL
        image = Image.open(image_path)
        
        # Use Tesseract to extract text
        text = pytesseract.image_to_string(image)
        return text
    except Exception as e:
        return f"Error: {e}"

def extract_field_values(text):
    """
    Extract specific field values from the OCR text using patterns.
    
    Args:
        text (str): Extracted text from the image.
        
    Returns:
        dict: A dictionary containing extracted field values.
    """
    try:
        # Patterns for extracting fields
        patterns = {
            "Chassis Number": r"Enter Search Element:\*\s*\|\s*([A-Z0-9]+)",
            "Registration Number": r"Registration No:?[\|]?\s*([A-Z0-9]+)\s*Fuel Type:",
            "Mfg. Year": r"Mfg\. Year:\s*\|?\s*([0-9/]+)",
        }
        
        # Extract values using the patterns
        extracted_values = {}
        for field, pattern in patterns.items():
            match = re.search(pattern, text)
            if match:
                extracted_values[field] = match.group(1)
            else:
                extracted_values[field] = "Not Found"
        
        # Extract 'Date Of Registration' field separately using custom logic
        extracted_values["Registration Date"] = extract_last_date(text)
        
        return extracted_values
    except Exception as e:
        return {"Error": str(e)}

def extract_last_date(text):
    """
    Extract the last date format from a line containing 'Date Of Registration'.
    
    Args:
        text (str): Input text containing the "Date Of Registration".
        
    Returns:
        str: Extracted registration date or 'Not Found'.
    """
    # Split the text into lines
    lines = text.splitlines()
    for line in lines:
        if "Date Of Registration" in line:
            print(f"Debug Line: {line}")  # Debugging: Print the line
            # Regex to capture the last date-like pattern in the line
            pattern = r"(\d{1,2}/\d{1,2}/\d{4})$"
            match = re.search(pattern, line)
            if match:
                return match.group(1).strip()
    return "Not Found"


def process_folder(folder_path):
    """
    Process all images in a given folder and extract field values.
    
    Args:
        folder_path (str): Path to the folder containing images.
    """
    # Supported image file extensions
    valid_extensions = {".jpg", ".jpeg", ".png", ".tiff", ".bmp", ".gif"}
    
    # Loop through all files in the folder
    for file_name in os.listdir(folder_path):
        # Construct the full path to the file
        file_path = os.path.join(folder_path, file_name)
        
        # Check if the file is an image based on the extension
        if os.path.isfile(file_path) and os.path.splitext(file_name.lower())[1] in valid_extensions:
            print(f"\nProcessing: {file_name}")
            
            # Extract text from the image
            extracted_text = extract_text_from_image(file_path)
            
            # Extract field values from the text
            field_values = extract_field_values(extracted_text)
            
            # Print the extracted values
            print("Extracted Field Values:\n", field_values)
            #print("Extracted Text:\n", extracted_text)
        else:
            continue
            # print(f"Skipping non-image file: {file_name}")

# Path to the folder containing images
folder_path = r"C:\Users\welcome\Documents\Carrum\Screenshot and pdf in screenshot"

# Process all images in the folder
process_folder(folder_path)
# Out:
# Processing: WhatsApp Image 2024-11-29 at 14.58.16_849056a5.jpg
# Debug Line: Engine No:iK10CNC5XXXXX Date Of Registration:02/09/2024
# Extracted Field Values:
#  {'Chassis Number': 'MA3JMTB1SRFB18876', 'Registration Number': 'TGO7T5651', 'Mfg. Year': '06/06/2024', 'Registration Date': '02/09/2024'}
#
# Processing: WhatsApp Image 2024-11-29 at 14.58.52_a0282b93.jpg
# Debug Line: Engine No:IK10CNCSXXXXX Date Of Registration:02/09/2024
# Extracted Field Values:
#  {'Chassis Number': 'MA3JMTB1SRFB18866', 'Registration Number': 'TGO7T5655', 'Mfg. Year': '06/06/2024', 'Registration Date': '02/09/2024'}
#
# Processing: WhatsApp Image 2024-11-29 at 15.00.06_4ec87ba9.jpg
# Debug Line: Engine No:IK10CNC5XXXXX Date Of Registration:02/09/2024
# Extracted Field Values:
#  {'Chassis Number': 'MA3JMTB1SRFB18918', 'Registration Number': 'TGO7T5657', 'Mfg. Year': '06/06/2024', 'Registration Date': '02/09/2024'}
#
# Processing: WhatsApp Image 2024-11-30 at 13.10.58_7068a1cc.jpg
# Debug Line: Engine No:|K10CNC6XXXXX Date Of Registration:/3 1/08/2024
# Extracted Field Values:
#  {'Chassis Number': 'MA3JMTB1SRGB30324', 'Registration Number': 'TG0O7T5551', 'Mfg. Year': '07/07/2024', 'Registration Date': '1/08/2024'}
#
# Processing: WhatsApp Image 2024-11-30 at 13.12.17_415afcd2.jpg
# Debug Line: Engine No:|K10CNC5XXXXX Date Of Registration:/3 1/08/2024
# Extracted Field Values:
#  {'Chassis Number': 'MA3JMTB1SRFB19421', 'Registration Number': 'TGO7T5552', 'Mfg. Year': '06/06/2024', 'Registration Date': '1/08/2024'}

# %%
import re

def extract_registration_date(text):
    """
    Extract the last date format from a line containing 'Date Of Registration'.
    
    Args:
        text (str): Input text containing the "Date Of Registration".
        
    Returns:
        str: Extracted registration date or 'Not Found'.
    """
    # Ensure the line contains 'Date Of Registration'
    if "Date Of Registration" in text:
        # Regex to capture the last date-like pattern in the line
        pattern = r"Date Of Registration.*?([0-9]{1,2}/[0-9]{1,2}/[0-9]{4})$"
        
        # Search for the pattern
        match = re.search(pattern, text)
        if match:
            # Return the matched date
            return match.group(1).strip()
    
    # Return 'Not Found' if no date pattern is detected
    return "Not Found"

# Test cases
texts = [
    "Engine No:|K10CNC6XXXXX Date Of Registration:/3 1/08/2024",  # OCR noise
    "Engine No:IK10CNC5XXXXX Date Of Registration:02/09/2024",    # Valid date
    "Engine No:|K10CNC5XXXXX Date Of Registration:0/3 1/08/2024", # OCR noise before the valid date
    "Engine No:|K10CNC5XXXXX Date Of Registration:"               # Missing date
]

# Apply the function to each test case and print the results
for text in texts:
    print(f"Input: {text}")
    print(f"Extracted Date: {extract_registration_date(text)}\n")
# Out:
# Input: Engine No:|K10CNC6XXXXX Date Of Registration:/3 1/08/2024
# Extracted Date: 1/08/2024
#
# Input: Engine No:IK10CNC5XXXXX Date Of Registration:02/09/2024
# Extracted Date: 02/09/2024
#
# Input: Engine No:|K10CNC5XXXXX Date Of Registration:0/3 1/08/2024
# Extracted Date: 1/08/2024
#
# Input: Engine No:|K10CNC5XXXXX Date Of Registration:
# Extracted Date: Not Found

# %% [markdown]
# # Extract Data in Images

# %%
import pytesseract
from PIL import Image
import re

# Specify the path to the Tesseract executable
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def extract_text_from_image(image_path):
    """
    Extract text from an image using Tesseract OCR.
    
    Args:
        image_path (str): Path to the image file.
        
    Returns:
        str: Extracted text from the image.
    """
    try:
        # Open the image using PIL
        image = Image.open(image_path)
        
        # Use Tesseract to extract text
        text = pytesseract.image_to_string(image)
        return text
    except Exception as e:
        return f"Error: {e}"

def extract_field_values(text):
    """
    Extract specific field values from the OCR text using patterns.
    
    Args:
        text (str): Extracted text from the image.
        
    Returns:
        dict: A dictionary containing extracted field values.
    """
    try:
        # Patterns for extracting fields
        patterns = {
            "Chassis Number": r"Enter Search Element:\*\s*\|\s*([A-Z0-9]+)",
            "Registration Number": r"Registration No:\s*([A-Z0-9]+)\s*Fuel Type:",
            "Mfg. Year": r"Mfg\. Year:\|([0-9/]+)\s*",
            "Registration Date": r"Date Of Registration:([0-9/]+)"
        }
        
        # Extract values using the patterns
        extracted_values = {}
        for field, pattern in patterns.items():
            match = re.search(pattern, text)
            if match:
                extracted_values[field] = match.group(1)
            else:
                extracted_values[field] = "Not Found"
        
        return extracted_values
    except Exception as e:
        return {"Error": str(e)}

# Path to the uploaded image
image_path = r"C:\Users\welcome\Documents\Carrum\WhatsApp Image 2024-11-30 at 12.49.19_c8f14133.jpg"

# Extract text
extracted_text = extract_text_from_image(image_path)

# Extract field values from the text
field_values = extract_field_values(extracted_text)

#Print extracted values
print("Extracted Text:\n", extracted_text)
print("\nExtracted Field Values:\n", field_values)
# Out:
# Extracted Text:
#  (>) M-wallet
#
# Duorre gebds dare wD
#
# OF REGISTRAION
#
# Regn, Number : TG07T8371
# _CARRUM MOBILITY
# Regd. Owner “SOLU
# _F NO 504 ANURAG TWRS
# Address “100 FT RD, BEST
# _MARUTI TOUR H3 CNG
# Maker's Class “IL SMT BSVI-PH2
# Vehicle Class : Motor Cab
# Mth. Ye. of Mfg + 10/10/2024
# Fucl Used : CNG PETROL
#
# Chassis Number: MA3JMTB1SRKB85779
#
# Engine Number K10CNC702804
# Cubuie Capacity
#
# Wheel Base
#
# Seating Capacity +5
#
# Unladen Weight
#
# Color : SUPERIOR WHITE
#
# 0/11/2024
# 9/11/2026
# 8/11/2036
#
# Date of Registration
# Regn. Valid Upto
# Tax
#
# Hypothecated To
#
# sult
#
# Registering Authority
#
# Signature of the Owner RTMRARGARERDS
#
# INSURANCE
#
# PTAILS
#
# Vehicle Number BnGonEs374
#
# SHARE THIS CARD DELETE THIS CARD
#
#
#
# Extracted Field Values:
#  {'Chassis Number': 'Not Found', 'Registration Number': 'Not Found', 'Mfg. Year': 'Not Found', 'Registration Date': 'Not Found'}

# %% [markdown]
# # Images In PDF

# %%
import fitz  # PyMuPDF
import pytesseract
from PIL import Image
import io

# Specify the path to the Tesseract executable
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def extract_images_from_pdf(pdf_path):
    """
    Extract images from a PDF file and return a list of image objects.
    
    Args:
        pdf_path (str): Path to the PDF file.
        
    Returns:
        list: A list of PIL Image objects.
    """
    doc = fitz.open(pdf_path)
    images = []
    
    # Loop through each page
    for page_num in range(len(doc)):
        page = doc.load_page(page_num)
        
        # Get the images on the page
        image_list = page.get_images(full=True)
        
        for img_index, img in enumerate(image_list):
            xref = img[0]
            
            # Extract the image in a format that can be used by PIL
            base_image = doc.extract_image(xref)
            image_data = base_image["image"]
            
            # Convert the image data to a PIL Image
            image = Image.open(io.BytesIO(image_data))
            images.append(image)
    
    return images

def extract_text_from_image(image):
    """
    Extract text from an image using Tesseract OCR.
    
    Args:
        image (PIL.Image): The image to process.
        
    Returns:
        str: The extracted text from the image.
    """
    return pytesseract.image_to_string(image)

def extract_text_from_pdf(pdf_path):
    """
    Extracts all text from the images within a PDF file.
    
    Args:
        pdf_path (str): Path to the PDF file.
        
    Returns:
        str: The extracted text from all images.
    """
    images = extract_images_from_pdf(pdf_path)
    extracted_text = ""
    
    # Process each image and extract text
    for image in images:
        extracted_text += extract_text_from_image(image)
    
    return extracted_text

# Example usage
pdf_path = r"C:\Users\welcome\Documents\Carrum\Screenshot and pdf in screenshot\MA3JMTB1SRFB18876 Invoice & Policy.pdf"  # Path to your PDF file
extracted_text = extract_text_from_pdf(pdf_path)

# Print extracted text from images
print(extracted_text)
# Out:
# GST No. 36AABCV2471Q1ZT VARUN MOTORS PVT. LTD .marutiid$ suzur
#
# MARUTI AUTHORISED DEALERS
#
# BEGUMPET : 1-10-177,
# "VARUN TOWERS", HYDERABAD -16. | Road No.2, HYDERABAD - 34.
#
# Ph : 4460 7676, Fax : 6632 7676
# varun.hyd.sal1 @ marutidealers.com
#
# BANJARA HILLS : 8-2-120/76/115,] KUKATPALLY : Opp. Chermas,
#
# Hydernagar, HYDERABAD - 72
#
# Ph: 4488 7676. Telefax : 2360 7676 | Ph : 4458 7676, 2389 7676 :
# varun.hyd.sal2@ marutidealers.com | varun.hyd.sal3@ marutidealers.com | varun-hyd.sal4@marutidealers.com
#
# VANASTHALIPURAM : Plot No. VI & Vil, A&B,
#
# Ward No. 4, Block No. 10, Autonagar,
# HYDERABAD - 70. Ph: 2402 7676
#
# GACHIBOWLI: Sy. No. 115/P,
# Beside Infotech, Gachibowli,
# HYDERABAD. Ph: 4949 7676,
#
# varun.hyd.sal5 @ marutidealers.com
#
# VARUN
# eH NAT POR R R .
# TAX / VEHICLE & CHARGES INVOICE io] poh h eal oat i]
# Sold To : M/S. ORIX LEASING AND FINANCIAL SERVICES INDIALTD bial IGOR DER
# Guardian of bs 5 = Barts etd ane
# a Oe ea oO 5
# Address > 8-2-293/82/A/974 JUBILEE HILLS ROAD NO 49 Serene Orta
# HYDERABAD Pin:500033,(M):9000906205 Bal te spa ae anced
# The f it
# TELANGANA (36) rhe res lac shs Waa
# Customer ID : 2144529482 PAN No : AABCI9186R REAL de as Si
# Financed By : ORIX LEASING & FINANCIAL SERVICES INDIA ETE,
# LIMITED, 8-2-293/82/A/974 JUBILEE HILLS ROAD NO
# 49 :
# CuistemertadharRe, 2 ca : heer
# nvoice Date : 08/2024 01:
# Place of Supply - TELANGANA(36) Order No : ee peat shia
# Vehicle ID : MA3JMTB1SRFB18876 Order Date : 29/08/2024
# Customer Mobile No. : :
# : 9000906205 Key No. - 1034
# Delivered To : CARRUM MOBILITY SOLUTIONS PVT LTD Booking Dealer 7
# Address : FNO-504, ANURAG TOWERS, 100 FET RD SIDHI Delivery Dealer : 4603
# VINAYAKA NAGAR AYYAPA SOCIETY MADHAPUR Customer GST No. : 86AABCI9186R1ZM
# HYD HYDERABAD Pin:500081,(M):6304982820 Dealer GST No. : 36AABCV2471Q1ZT
# TELANGANA (36) Dealer PAN No. : AABCV2471Q
# IRN 6acbba5666b3b20da1c7379dddae69674fbdd9d8cf1 941e16542e447d8e008f0
# Price Dr Amount __Gr Amount_
# 1 PRICE OF ONE MARUTI TOUR H3 CNG 1L SMT- 4,97,286.96
# WARCIT1
# CHASSIS NO. ENGINE NO. COLOR HSN EMISSION NORM
# MA3JMTB1SRFB18876 K10CN C597072 Superior White-26U 87032191 Bharat Stage 6
# p g
# 2 Discount for Corp/Institutional/RSL Customer 0.00 15,504.00
# 3 DISCOUNT 0.00 - 15,504.00
# 4 MSSF Special Offer 0.00 7 0.00
# 5S Additional Discount 2 0.00 ie 0.00
# 6 Additional Discount 1 0.00 0.00
# 7 Scrappage Discount 0.00 — - 0.00
# 8 Exchange / Loyalty Bonus Discount “0.00 0.00
# 9 Assessable Value 4,66,278.96 as
# 10 CGST @14% 65,279.05 i
# 11 SGST @ 14% 65,279.05 - os
# 12 Cess@1% 4,662.78 -
# Sub Total Amount (Assessable Value + Tax) : 6,01,499.84 - _
# Total Round Off Amount 0.16
# Total Invoice Amount 6,01,500.00
# Invoice Amount in words : Rupees Six Lakh One Thousand Five Hundred Only
# Loyalty Additional bonus point are awarded in customer loyalty account :
# Loyalty Points Redemption
# Customer Name & Signatory For VARUN MOTORS PVT LTD
#
# (M/S. ORIX LEASING AND FINANCIAL SERVICES INDIALTD)
#
# Created By VENKATA SWAMY KYATHAM
#
# =x
# = S
#
# Caring for Customers
# WORKSHOPS : i 4548 Yais
# Begumpet @: 44757979 Gachibowli @:
# Balanagar @:4477 7979 ECIL @: 6454 7676
#
# Malakpet @®:24547676 Jubilee Hills@: 2360 7575
# i i : 6463 7676 BHEL @: 4800 4900
# Tolichowki 1:6 tiered
#
# Auto Nagar #: 2402 7676 MQSW
# Mothinagar @: 2383 7676
#
# Created Date:
#
# NOT VALID FOR
#
# REGISTRATION
#
# 4 MARI
#
# (Authorized Signatory)
# 30-AUG-2024 13:38:44
#
# \|TrueWValue
#
# %
#
# Begumpet
# Madinaguda
# Habsiguda
# Gachibowli
#
# -
# owns
#
# TRUE VALUES :
#
# @: 4460 7614
# @: 6463 3657
# @: 6555 7676
# @: 4949 7977
#
# Vanasthalupuram @: 6456 0932
#
# (OFFICE COPY)
#
# MARUTI
# SCHOOL
#
# Oeive witm Comnipeect
#
# DRIVING SCHOOLS:
#
# Madinaguda ®: 4477 7676
# Gachibowli @: 4949 7999
# Auto Nagar @: 2402 7676
# Begumpet @: 2776 1991
# Jubilee Hills @: 2360 7575
#
# | MUDWHIGI
# This policy is sourced and serviced by.
#
# Maruti Suzuki Insurance Broking Private Limited Support
# 1, Nelson Mandela Road, Vasant Kunj, New Delhi - 110070
#
# 3377 4477
# This is not a part of the policy document. Please Detach Here. prefix 011/022/033/044
#
# Bajaj Allianz General Insurance Co. Ltd.
# IRDAI Regn. No. 113. CIN - U66010PN2000PLC015329
#
# CERTIFICATE CUM POLICY SCHEDULE
#
# ORIGINAL FOR RECIPIENT / DUPLICATE FOR SUPPLIER
# TAX INVOICE/CERTIFICATE CUM POLICY SCHEDULE
# (FORM St OF THE CENTRAL MOTOR VEHICLES RULES, 1989)
#
# Package Policy (Commercial Vehicle - Passenger Carrying) & Proposal No & Date N0005310850 / 30-Aug-2024 20:50
# Policy Type & UIN . ; .
# LED SST SE EE enw Period of Insurance 31-AUG-2024 10:00 to 30-AUG-2025 23:59
#
# Policy No OG-25-9910-1803-00032345
#
# Vehicle Identification No. MA3JMTBISRFB18876
#
# Policy Issued On 31-Aug-2024 10:00
#
# Geographical Arca India
# Insured Name
#
# M/S CARRUM MOBILITY SOLUTIONS PRIVATE LIMITED
#
# GST No & State 36AALCC8489RIZE | Telangana
#
# Invoice No N0005310850
#
# REF BY SADAMUDDIN CHOUHAN, FNO 504 ANURAG TOWERS,
# 100 FEET ROAD, AYYAPPA SOCIETY SIDDI VINAYAKA
# NAGAR, MADHAPUR, CYBERABAD , TELANGANA-50008 1
#
# Accounting Code of Service - | 997134
#
# Insured Address
#
# Telangana - 36
#
# Place of Supply Telangana GSTIN of Customer
#
# 36AALCCR489RIZE
# _ MOTOR VEHICLE DETAILS ~ _
# Make Maruti Suzuki Seating Capacity
# Model - Variant MARUTI TOUR I13 CNG IL SMT BS6 Type of Body | Color Hatchback | SUPERIOR WHITE
# Registration No Fuel Type CNG/Petrol
#
# Year of Manufacture 2024 RTO Location RANGA REDDY | TS-07
# Engine - Chassis No K10CNC597072 - MA3JMTBISRFBI8876 Zone
# Cubic Capacity 998 FASTag ID
#
# 601500 |
#
# Non Electrical Accessories =
#
# _ Insured Declared Value(®) __
# _| Electrical Accessories % [lo ———__| CNG/LPG Kit? |
#
# Schedule of Premium(Amount in 2)
#
# { Vehicle z
#
# [ OWN DAMAGE SECTION (A) LIABILITY SECTION (B
# Vehicle 23839 | Basic Third Party Liability % 10688
# Extra premium towards inbuilt CNG/LPG % 192 | Third Party Liability for Bi-fucl Kit %60
# Basic Premium 2% 4031 | Legal Liability (WC) to Driver (IMT-28) = 100
# Depreciation Shield(IRDAN113RP0027V01200102/A0002V01201213) % 3008 | Net Liability Premium (B) = 10848
# Net own Damage Premium (A) % 7039 |_Total Premium (A+B) 17887
# CGST @9% % 1609.83
# SGST @9% % 1609.83
# Gross Premium Paid % 21107
# MISP - VARUN MOTORS PVT LTD
# Notes:-
#
# I. Policy Issuance is subject to realisation of premium.
#
# . Consolidate stamp duty paid to State Exchequer.
#
# . Policy is subject to a compulsory Deductible of Rs. 500
#
# . Voluntary excess Rs. 0
#
# . Subject to Endorsements IMT 28
#
# 6. Warranted that the insured named herein/owner of the vehicle holds a valid Pollution
# Under Control (PUC) Certificate and/or valid Fitness certificate, as applicable, on the
# date of commencement of the Policy and undertakes to renew and maintain a valid and
# effective PUC and/or fitness Certificate, as applicable, during the subsistence of the
# Policy. Further, the company reserves the right to take appropriate action in case of any
#
# “discrepancy in the PUC or fitness certificate.
#
# Bwn
#
# wn
#
# Financier Details
#
# Financier Type: Financed Financier Name: ORIX LEASING AND FINANCIAL SERVICES Financier Branch: JUBILEE HILLS
#
# Payment Details
#
# Payment Mode: Credit Card Cheque No/Transaction No: 78708379757 Bank Name: ICICI BANK LIMITED Amount: 21107
#
# {Limitations as to use:- The Policy covers use only under a permit within the meaning of the Motor Vehicle Act, 1988 or such a carriage falling under Sub-scction 3 of Section 66 of the Motor Vehicle's Act 1988.The
# |Poticy does not cover use for: (1) Organised racing, (2) Pace Making (3) Reliability Trials, (4) Speed Testing (S) Use whilst drawing a trailer except the towing (other than for reward) of any one disabled mechanically
# \propelled vehicle
#
# frersane or Classes of Persons entitled to drive:- Any person including insured: Provided that a person driving holds an effective driving license at the time of the accident and is not disqualitied from holding or
# jobtaining such a license. Provided also that the person holding an effective learmer’s license may also drive the vehicle when not used for the transport of passengers at the time of the accident and that such a person
# satisfies the requirements of Rule 3 of the Central Motor Vehicles Rules, 1989. : . ;
#
# Limits of Lfability:- Under Section If -1(i) of the Policy - Death of or bodily injury - Such amount as is necessary to meet the requirements of the Motor Vehicles Act, 1988. Under Section II -I(it) of the Policy - Damage!
# tu Third Party Property - Rs. LBLTPP (as per JMT 20)in respect of any one claim or series of claims arising out of one event. Personal Accident cover for Owner - Driver under section IV: Capital Sum Insured (CSI) - Rs.
# |LBLDUS Deductible under Section-I: LBLDED (Compulsory Deductible Rs. L3LCD and Imposed Deductible Rs. 0)
#
# iNo Claim Bonus:- The insured is entitled for a No Claim Bonus (NCB) on the Own Damage section of the policy, if no claim is made or pending during the preceding year (s), as per the: The preceding year/20%,
# Preveding Two consecutive years’25%, Preceding Three consecutive years/35%, Preceding Four consecutive years/45%, Preceding Five consecutive years/50% of NCB on OD Premium. No Claim Bonus will only be
# allowed provided the policy is renewed within 90 days of the expiry date of the previous policy. : a
# IMPORTANT NOTICE? the Insured is not indemnified if the vehicle is used or driven otherwise than in accordance with this Schedule. Any payment made by the Company by reason of wider terms appearing in the
# Certificate in order to comply with the Motor Vehicle Act, 1988 is recoverable from the Insured. Sce the clause headed "AVOIDANCE OF CERTAIN TERMS AND RIGHT OF RECOVERY", For Legal
# interpretation, English version will hold good. : .
#
# For information on ombudsman you may visit website : https://www.ciolns.co.in/Ombudsman:- I / We hereby certily that the Policy to which the certificate relates as well as this certificate of insurance are issued
# in accordance with the provision of Chapter X_and Chapter XI of M.V, Act, 1988,
#
# For Bajaj Allianz General Insurance Company Limited
#
# Authorised Signatory
#
# Policy Issuing Office :North East Plaza, 4th Floor, Beside BMW Showroom, Opp: RTA office, Erramanzil X Roads, Hyderabad - 500082
# GSTIN: 36AABCB5730G1ZY. CIN No: . State Name: Telangana
#
# : _ This Policy is sourced and sery iced by Marali Sucuki Insurance Broking Private Limited ;
# Direct Broker (General) IRDAI License No. 428, valid tll 01 February 2027, Mail ID: support@msibpl.co.in, Contact: 33774477 (Prefix 011/022/033/044)

# %%
# !pip install --upgrade pandas openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\welcome\anaconda3\lib\site-packages (2.1.4)
# Collecting pandas
#   Using cached pandas-2.2.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: openpyxl in c:\users\welcome\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\welcome\appdata\roaming\python\python311\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\welcome\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\welcome\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\welcome\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: et-xmlfile in c:\users\welcome\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\welcome\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.3-cp311-cp311-win_amd64.whl (11.6 MB)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
#   Rolling back uninstall of pandas
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas-2.1.4.dist-info\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\~andas-2.1.4.dist-info
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\__init__.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\__init__.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\__pycache__\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\~_pycache__
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\_config\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\~config
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\_libs\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\~libs
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\_testing\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\~testing
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\_typing.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\_typing.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\_version.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\_version.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\_version_meson.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\_version_meson.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\api\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\~pi
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\arrays\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\~rrays
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\compat\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\~ompat
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\conftest.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\conftest.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\__init__.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\__init__.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\__pycache__\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\core\~_pycache__
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\_numba\__init__.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\_numba\__init__.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\_numba\__pycache__\__init__.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\_numba\__pycache__\__init__.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\_numba\__pycache__\executor.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\_numba\__pycache__\executor.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\_numba\executor.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\_numba\executor.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\_numba\kernels\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\core\_numba\~ernels
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\accessor.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\accessor.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\algorithms.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\algorithms.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\api.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\api.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\apply.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\apply.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\array_algos\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\core\~rray_algos
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arraylike.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arraylike.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\__init__.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\__init__.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\__pycache__\__init__.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\__pycache__\__init__.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\__pycache__\_arrow_string_mixins.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\__pycache__\_arrow_string_mixins.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\__pycache__\_mixins.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\__pycache__\_mixins.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\__pycache__\_ranges.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\__pycache__\_ranges.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\__pycache__\base.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\__pycache__\base.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\__pycache__\boolean.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\__pycache__\boolean.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\__pycache__\categorical.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\__pycache__\categorical.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\__pycache__\datetimelike.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\__pycache__\datetimelike.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\__pycache__\datetimes.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\__pycache__\datetimes.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\__pycache__\floating.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\__pycache__\floating.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\__pycache__\integer.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\__pycache__\integer.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\__pycache__\interval.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\__pycache__\interval.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\__pycache__\masked.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\__pycache__\masked.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\__pycache__\numeric.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\__pycache__\numeric.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\__pycache__\numpy_.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\__pycache__\numpy_.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\__pycache__\period.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\__pycache__\period.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\__pycache__\string_.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\__pycache__\string_.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\__pycache__\string_arrow.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\__pycache__\string_arrow.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\__pycache__\timedeltas.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\__pycache__\timedeltas.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\_arrow_string_mixins.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\_arrow_string_mixins.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\_mixins.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\_mixins.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\_ranges.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\_ranges.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\arrow\__init__.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\arrow\__init__.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\arrow\__pycache__\__init__.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\arrow\__pycache__\__init__.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\arrow\__pycache__\_arrow_utils.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\arrow\__pycache__\_arrow_utils.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\arrow\__pycache__\array.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\arrow\__pycache__\array.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\arrow\__pycache__\extension_types.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\arrow\__pycache__\extension_types.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\arrow\_arrow_utils.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\arrow\_arrow_utils.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\arrow\array.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\arrow\array.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\arrow\extension_types.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\arrow\extension_types.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\base.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\base.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\boolean.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\boolean.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\categorical.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\categorical.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\datetimelike.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\datetimes.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\floating.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\floating.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\integer.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\integer.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\interval.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\interval.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\masked.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\masked.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\numeric.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\numeric.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\numpy_.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\numpy_.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\period.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\period.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\sparse\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\core\arrays\~parse
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\string_.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\string_.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\string_arrow.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\string_arrow.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\arrays\timedeltas.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\arrays\timedeltas.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\base.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\base.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\common.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\common.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\computation\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\core\~omputation
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\config_init.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\config_init.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\construction.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\construction.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\dtypes\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\core\~types
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\flags.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\flags.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\frame.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\frame.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\generic.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\generic.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\groupby\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\core\~roupby
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\indexers\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\core\~ndexers
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\indexes\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\core\~ndexes
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\indexing.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\indexing.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\interchange\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\core\~nterchange
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\internals\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\core\~nternals
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\methods\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\core\~ethods
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\missing.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\missing.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\nanops.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\nanops.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\ops\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\core\~ps
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\resample.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\resample.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\reshape\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\core\~eshape
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\roperator.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\roperator.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\sample.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\sample.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\series.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\series.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\shared_docs.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\shared_docs.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\sorting.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\core\sorting.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\sparse\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\core\~parse
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\strings\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\core\~trings
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\tools\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\core\~ools
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\util\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\core\~til
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\core\window\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\core\~indow
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\errors\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\~rrors
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\__init__.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\__init__.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\__pycache__\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\io\~_pycache__
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\_util.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\_util.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\api.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\api.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\clipboard\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\io\~lipboard
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\clipboards.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\clipboards.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\common.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\common.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\excel\__init__.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\excel\__init__.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\excel\__pycache__\__init__.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\excel\__pycache__\__init__.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\excel\__pycache__\_base.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\excel\__pycache__\_base.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\excel\__pycache__\_odfreader.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\excel\__pycache__\_odfreader.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\excel\__pycache__\_odswriter.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\excel\__pycache__\_odswriter.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\excel\__pycache__\_openpyxl.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\excel\__pycache__\_openpyxl.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\excel\__pycache__\_pyxlsb.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\excel\__pycache__\_pyxlsb.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\excel\__pycache__\_util.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\excel\__pycache__\_util.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\excel\__pycache__\_xlrd.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\excel\__pycache__\_xlrd.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\excel\__pycache__\_xlsxwriter.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\excel\__pycache__\_xlsxwriter.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\excel\_base.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\excel\_base.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\excel\_odfreader.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\excel\_odfreader.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\excel\_odswriter.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\excel\_odswriter.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\excel\_openpyxl.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\excel\_openpyxl.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\excel\_pyxlsb.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\excel\_pyxlsb.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\excel\_util.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\excel\_util.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\excel\_xlrd.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\excel\_xlrd.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\excel\_xlsxwriter.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\excel\_xlsxwriter.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\feather_format.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\feather_format.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\formats\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\io\~ormats
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\gbq.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\gbq.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\html.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\html.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\json\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\io\~son
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\orc.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\orc.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\parquet.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\parquet.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\parsers\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\io\~arsers
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\pickle.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\pickle.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\pytables.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\pytables.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\sas\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\io\~as
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\spss.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\spss.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\sql.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\sql.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\stata.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\stata.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\io\xml.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\io\xml.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\plotting\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\~lotting
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\pyproject.toml
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\pyproject.toml
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\testing.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\testing.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\__init__.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\__init__.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\__pycache__\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\~_pycache__
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\api\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\~pi
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\__init__.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\__init__.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\__pycache__\__init__.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\__pycache__\__init__.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\__pycache__\common.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\__pycache__\common.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\__pycache__\conftest.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\__pycache__\conftest.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\__pycache__\test_frame_apply.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\__pycache__\test_frame_apply.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\__pycache__\test_frame_apply_relabeling.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\__pycache__\test_frame_apply_relabeling.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\__pycache__\test_frame_transform.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\__pycache__\test_frame_transform.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\__pycache__\test_invalid_arg.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\__pycache__\test_invalid_arg.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\__pycache__\test_series_apply.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\__pycache__\test_series_apply.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\__pycache__\test_series_apply_relabeling.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\__pycache__\test_series_apply_relabeling.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\__pycache__\test_series_transform.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\__pycache__\test_series_transform.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\__pycache__\test_str.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\__pycache__\test_str.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\common.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\common.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\conftest.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\conftest.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\test_frame_apply.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\test_frame_apply.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\test_frame_apply_relabeling.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\test_frame_apply_relabeling.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\test_frame_transform.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\test_frame_transform.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\test_invalid_arg.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\test_invalid_arg.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\test_series_apply.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\test_series_apply.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\test_series_apply_relabeling.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\test_series_apply_relabeling.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\test_series_transform.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\test_series_transform.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\apply\test_str.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\apply\test_str.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arithmetic\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\~rithmetic
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\__init__.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\arrays\__init__.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\__pycache__\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\arrays\~_pycache__
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\boolean\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\arrays\~oolean
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\categorical\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\arrays\~ategorical
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\datetimes\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\arrays\~atetimes
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\floating\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\arrays\~loating
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\integer\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\arrays\~nteger
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\interval\__init__.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\arrays\interval\__init__.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\interval\__pycache__\__init__.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\arrays\interval\__pycache__\__init__.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\interval\__pycache__\test_astype.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\arrays\interval\__pycache__\test_astype.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\interval\__pycache__\test_interval.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\arrays\interval\__pycache__\test_interval.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\interval\__pycache__\test_ops.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\arrays\interval\__pycache__\test_ops.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\interval\test_astype.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\arrays\interval\test_astype.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\interval\test_interval.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\arrays\interval\test_interval.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\interval\test_ops.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\arrays\interval\test_ops.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\masked\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\arrays\~asked
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\masked_shared.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\arrays\masked_shared.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\numpy_\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\arrays\~umpy_
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\period\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\arrays\~eriod
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\sparse\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\arrays\~parse
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\string_\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\arrays\~tring_
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\test_array.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\arrays\test_array.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\test_datetimelike.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\arrays\test_datetimelike.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\test_datetimes.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\arrays\test_datetimes.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\test_ndarray_backed.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\arrays\test_ndarray_backed.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\test_period.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\arrays\test_period.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\test_timedeltas.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\arrays\test_timedeltas.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\arrays\timedeltas\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\arrays\~imedeltas
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\base\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\~ase
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\computation\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\~omputation
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\config\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\~onfig
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\construction\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\~onstruction
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\__init__.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\__init__.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\__pycache__\__init__.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\__pycache__\__init__.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\__pycache__\test_array.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\__pycache__\test_array.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\__pycache__\test_astype.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\__pycache__\test_astype.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\__pycache__\test_clip.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\__pycache__\test_clip.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\__pycache__\test_constructors.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\__pycache__\test_constructors.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\__pycache__\test_core_functionalities.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\__pycache__\test_core_functionalities.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\__pycache__\test_functions.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\__pycache__\test_functions.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\__pycache__\test_indexing.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\__pycache__\test_indexing.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\__pycache__\test_internals.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\__pycache__\test_internals.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\__pycache__\test_interp_fillna.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\__pycache__\test_interp_fillna.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\__pycache__\test_methods.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\__pycache__\test_methods.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\__pycache__\test_replace.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\__pycache__\test_replace.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\__pycache__\test_setitem.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\__pycache__\test_setitem.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\__pycache__\test_util.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\__pycache__\test_util.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\__pycache__\util.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\__pycache__\util.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\index\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\copy_view\~ndex
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\test_array.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\test_array.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\test_astype.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\test_astype.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\test_clip.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\test_clip.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\test_constructors.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\test_constructors.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\test_core_functionalities.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\test_core_functionalities.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\test_functions.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\test_functions.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\test_indexing.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\test_indexing.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\test_internals.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\test_internals.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\test_interp_fillna.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\test_interp_fillna.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\test_methods.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\test_methods.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\test_replace.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\test_replace.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\test_setitem.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\test_setitem.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\test_util.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\test_util.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\copy_view\util.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\copy_view\util.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\dtypes\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\~types
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\extension\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\~xtension
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\frame\__init__.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\frame\__init__.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\frame\__pycache__\__init__.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\frame\__pycache__\__init__.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\frame\__pycache__\common.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\frame\__pycache__\common.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\frame\__pycache__\conftest.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\frame\__pycache__\conftest.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\frame\__pycache__\test_alter_axes.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\frame\__pycache__\test_alter_axes.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\frame\__pycache__\test_api.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\frame\__pycache__\test_api.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\frame\__pycache__\test_arithmetic.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\frame\__pycache__\test_arithmetic.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\frame\__pycache__\test_block_internals.cpython-311.pyc
# ...
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\methods\test_to_frame.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\methods\test_to_numpy.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\methods\test_to_numpy.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\methods\test_tolist.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\methods\test_tolist.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\methods\test_truncate.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\methods\test_truncate.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\methods\test_tz_localize.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\methods\test_tz_localize.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\methods\test_unique.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\methods\test_unique.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\methods\test_unstack.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\methods\test_unstack.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\methods\test_update.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\methods\test_update.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\methods\test_value_counts.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\methods\test_value_counts.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\methods\test_values.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\methods\test_values.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\methods\test_view.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\methods\test_view.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\test_api.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\test_api.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\test_arithmetic.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\test_arithmetic.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\test_constructors.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\test_constructors.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\test_cumulative.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\test_cumulative.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\test_iteration.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\test_iteration.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\test_logical_ops.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\test_logical_ops.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\test_missing.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\test_missing.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\test_npfuncs.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\test_npfuncs.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\test_reductions.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\test_reductions.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\test_repr.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\test_repr.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\test_subclass.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\test_subclass.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\test_ufunc.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\test_ufunc.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\test_unary.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\test_unary.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\series\test_validate.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\series\test_validate.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\strings\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\~trings
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\test_aggregation.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\test_aggregation.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\test_algos.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\test_algos.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\test_common.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\test_common.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\test_downstream.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\test_downstream.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\test_errors.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\test_errors.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\test_expressions.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\test_expressions.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\test_flags.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\test_flags.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\test_multilevel.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\test_multilevel.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\test_nanops.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\test_nanops.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\test_optional_dependency.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\test_optional_dependency.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\test_register_accessor.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\test_register_accessor.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\test_sorting.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\test_sorting.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\test_take.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\test_take.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tools\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\~ools
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tseries\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\~series
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\__init__.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\__init__.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\__pycache__\__init__.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\__pycache__\__init__.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\__pycache__\test_api.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\__pycache__\test_api.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\__pycache__\test_array_to_datetime.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\__pycache__\test_array_to_datetime.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\__pycache__\test_ccalendar.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\__pycache__\test_ccalendar.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\__pycache__\test_conversion.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\__pycache__\test_conversion.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\__pycache__\test_fields.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\__pycache__\test_fields.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\__pycache__\test_libfrequencies.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\__pycache__\test_libfrequencies.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\__pycache__\test_liboffsets.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\__pycache__\test_liboffsets.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\__pycache__\test_np_datetime.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\__pycache__\test_np_datetime.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\__pycache__\test_parse_iso8601.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\__pycache__\test_parse_iso8601.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\__pycache__\test_parsing.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\__pycache__\test_parsing.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\__pycache__\test_period_asfreq.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\__pycache__\test_period_asfreq.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\__pycache__\test_resolution.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\__pycache__\test_resolution.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\__pycache__\test_timedeltas.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\__pycache__\test_timedeltas.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\__pycache__\test_timezones.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\__pycache__\test_timezones.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\__pycache__\test_to_offset.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\__pycache__\test_to_offset.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\__pycache__\test_tzconversion.cpython-311.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\__pycache__\test_tzconversion.cpython-311.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\test_api.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\test_api.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\test_array_to_datetime.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\test_array_to_datetime.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\test_ccalendar.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\test_ccalendar.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\test_conversion.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\test_conversion.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\test_fields.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\test_fields.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\test_libfrequencies.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\test_libfrequencies.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\test_liboffsets.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\test_liboffsets.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\test_np_datetime.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\test_np_datetime.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\test_parse_iso8601.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\test_parse_iso8601.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\test_parsing.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\test_parsing.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\test_period_asfreq.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\test_period_asfreq.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\test_resolution.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\test_resolution.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\test_timedeltas.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\test_timedeltas.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\test_timezones.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\test_timezones.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\test_to_offset.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\test_to_offset.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\tslibs\test_tzconversion.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-2ge125o3\tests\tslibs\test_tzconversion.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\util\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\~til
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tests\window\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\tests\~indow
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\tseries\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\~series
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pandas\util\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\pandas\~til
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\welcome\\anaconda3\\Lib\\site-packages\\pandas.libs\\msvcp140-0f2ea95580b32bcfc81c235d5751ce78.dll'
# Consider using the `--user` option or check the permissions.
